# %% [markdown]
# # Artist Data Migration to Strapi API
#
# This notebook processes artist data from CSV and uploads it to the Strapi database via API.
#
# ## Process:
# 1. Load CSV data with artist information
# 2. Extract unique artists with their royalty rates
# 3. Clean and prepare data
# 4. Upload to API endpoint
# 5. Log results and handle errors

# %%
# Import required libraries
import pandas as pd
import numpy as np
import requests
import json
import os
from dotenv import load_dotenv
import logging
from typing import Dict, List, Optional
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

# Load environment variables
load_dotenv()

# API Configuration
API_BASE_URL = os.getenv('API_BASE_URL')
API_TOKEN = os.getenv('API_TOKEN')

if not API_BASE_URL or not API_TOKEN:
    raise ValueError("API_BASE_URL and API_TOKEN must be set in .env file")

logger.info(f"API Base URL: {API_BASE_URL}")
logger.info("API Token loaded successfully")
# Out:
# 2025-10-23 09:48:38,653 - INFO - API Base URL: http://localhost:1337/api
# 2025-10-23 09:48:38,653 - INFO - API Token loaded successfully

# %%
# Load CSV data
csv_file_path = 'data/All Product Data Back Up 070825.csv'

logger.info(f"Loading CSV file: {csv_file_path}")

try:
    # Read CSV file - only load relevant columns for efficiency
    df = pd.read_csv(
        csv_file_path,
        usecols=['Artist', 'Artist Royalty - Retail', 'Artist Royalty - Wholesale', 'Artist Royalty - Interiors']
    )
    logger.info(f"Successfully loaded {len(df)} rows from CSV")
    logger.info(f"Columns: {df.columns.tolist()}")
    
    # Display first few rows
    print("\nFirst 5 rows of data:")
    print(df.head())
    
except Exception as e:
    logger.error(f"Error loading CSV file: {e}")
    raise
# Out:
# 2025-10-23 09:48:43,767 - INFO - Loading CSV file: data/All Product Data Back Up 070825.csv
# 2025-10-23 09:48:52,786 - INFO - Successfully loaded 384349 rows from CSV
# 2025-10-23 09:48:52,786 - INFO - Columns: ['Artist', 'Artist Royalty - Retail', 'Artist Royalty - Wholesale', 'Artist Royalty - Interiors']
# First 5 rows of data:
#           Artist  Artist Royalty - Retail  Artist Royalty - Wholesale  \
# 0  The 13 Prints                     3.99                         1.1
# 1  The 13 Prints                     3.99                         1.1
# 2  The 13 Prints                     3.99                         1.1
# 3  The 13 Prints                     3.99                         1.1
# 4  The 13 Prints                     3.99                         1.1
#
#    Artist Royalty - Interiors
# 0                         1.4
# 1                         1.4
# 2                         1.4
# 3                         1.4
# 4                         1.4

# %%
# Process and clean data to get unique artists with their royalty rates
logger.info("Processing artist data...")

# Remove rows where Artist is null or empty
df_clean = df.dropna(subset=['Artist'])
df_clean = df_clean[df_clean['Artist'].str.strip() != '']

logger.info(f"After removing nulls/empties: {len(df_clean)} rows")

# Get unique artists with their royalty rates
# Using groupby to get the first occurrence of each artist's royalty rates
# (assuming royalty rates are consistent per artist)
unique_artists_df = df_clean.groupby('Artist', as_index=False).first()

logger.info(f"Found {len(unique_artists_df)} unique artists")

# Display the processed data
print("\nUnique Artists Data:")
print(unique_artists_df)
print(f"\nTotal unique artists: {len(unique_artists_df)}")

# Check for any missing royalty data
missing_retail = unique_artists_df['Artist Royalty - Retail'].isna().sum()
missing_wholesale = unique_artists_df['Artist Royalty - Wholesale'].isna().sum()
missing_interiors = unique_artists_df['Artist Royalty - Interiors'].isna().sum()

print(f"\nMissing data summary:")
print(f"  - Missing Retail Royalty: {missing_retail}")
print(f"  - Missing Wholesale Royalty: {missing_wholesale}")
print(f"  - Missing Interiors Royalty: {missing_interiors}")
# Out:
# 2025-10-23 09:48:52,793 - INFO - Processing artist data...
# 2025-10-23 09:48:52,865 - INFO - After removing nulls/empties: 381721 rows
# 2025-10-23 09:48:52,881 - INFO - Found 279 unique artists
# Unique Artists Data:
#               Artist  Artist Royalty - Retail  Artist Royalty - Wholesale  \
# 0             67 Inc                      NaN                         NaN
# 1         83 Oranges                     3.99                        1.10
# 2         Adam Graff                      NaN                         NaN
# 3          Aley Wild                     3.99                        1.10
# 4      Alice Straker                     3.99                        1.10
# ..               ...                      ...                         ...
# 274  Your Local Ross                     3.99                        1.10
# 275    apricot+birch                     3.99                        1.10
# 276       blanchouse                     3.99                        0.66
# 277         cartissi                     3.99                        1.10
# 278             m00d                     3.99                        1.10
#
#      Artist Royalty - Interiors
# 0                           NaN
# 1                           1.4
# 2                           NaN
# 3                           1.4
# 4                           1.4
# ..                          ...
# 274                         1.4
# 275                         1.4
# 276                         1.4
# 277                         1.4
# 278                         1.4
#
# [279 rows x 4 columns]
#
# Total unique artists: 279
#
# Missing data summary:
#   - Missing Retail Royalty: 76
#   - Missing Wholesale Royalty: 58
#   - Missing Interiors Royalty: 76

# %%
# Function to create artist via API
def create_artist(artist_data: Dict) -> Optional[Dict]:
    """
    Create an artist record in the Strapi database via API.
    
    Args:
        artist_data: Dictionary containing artist information
        
    Returns:
        Response data if successful, None if failed
    """
    endpoint = f"{API_BASE_URL}/artists"
    
    headers = {
        'Authorization': f'Bearer {API_TOKEN}',
        'Content-Type': 'application/json'
    }
    
    # Prepare payload according to Strapi format
    payload = {
        "data": artist_data
    }
    
    try:
        response = requests.post(endpoint, headers=headers, json=payload, timeout=30)
        
        if response.status_code == 200 or response.status_code == 201:
            logger.info(f"Successfully created artist: {artist_data.get('artist_name')}")
            return response.json()
        else:
            logger.error(f"Failed to create artist {artist_data.get('artist_name')}: {response.status_code}")
            logger.error(f"Response: {response.text}")
            return None
            
    except requests.exceptions.RequestException as e:
        logger.error(f"Network error creating artist {artist_data.get('artist_name')}: {e}")
        return None
    except Exception as e:
        logger.error(f"Unexpected error creating artist {artist_data.get('artist_name')}: {e}")
        return None

# Test function is defined
logger.info("Artist creation function defined successfully")
# Out:
# 2025-10-23 09:48:56,461 - INFO - Artist creation function defined successfully

# %%
# Prepare artist data for API upload
def prepare_artist_data(row) -> Dict:
    """
    Transform DataFrame row into API-compatible artist data format.
    
    Args:
        row: DataFrame row containing artist information
        
    Returns:
        Dictionary with API field names and cleaned values
    """
    artist_data = {
        "artist_name": str(row['Artist']).strip(),
        "artist_royalties_retail": None,
        "artist_royalties_wholesale": None,
        "artist_royalties_interiors": None
    }
    
    # Handle royalty values - convert to float if not null
    if pd.notna(row['Artist Royalty - Retail']):
        artist_data["artist_royalties_retail"] = float(row['Artist Royalty - Retail'])
    
    if pd.notna(row['Artist Royalty - Wholesale']):
        artist_data["artist_royalties_wholesale"] = float(row['Artist Royalty - Wholesale'])
    
    if pd.notna(row['Artist Royalty - Interiors']):
        artist_data["artist_royalties_interiors"] = float(row['Artist Royalty - Interiors'])
    
    return artist_data

# Prepare all artist records
artist_records = []
for idx, row in unique_artists_df.iterrows():
    artist_data = prepare_artist_data(row)
    artist_records.append(artist_data)

logger.info(f"Prepared {len(artist_records)} artist records for upload")

# Display sample prepared data
print("\nSample prepared artist data (first 3):")
for i, record in enumerate(artist_records[:3]):
    print(f"\n{i+1}. {json.dumps(record, indent=2)}")
# Out:
# 2025-10-23 09:48:58,540 - INFO - Prepared 279 artist records for upload
# Sample prepared artist data (first 3):
#
# 1. {
#   "artist_name": "67 Inc",
#   "artist_royalties_retail": null,
#   "artist_royalties_wholesale": null,
#   "artist_royalties_interiors": null
# }
#
# 2. {
#   "artist_name": "83 Oranges",
#   "artist_royalties_retail": 3.99,
#   "artist_royalties_wholesale": 1.1,
#   "artist_royalties_interiors": 1.4
# }
#
# 3. {
#   "artist_name": "Adam Graff",
#   "artist_royalties_retail": null,
#   "artist_royalties_wholesale": null,
#   "artist_royalties_interiors": null
# }

# %%
# Upload artists to API
logger.info("Starting artist upload process...")

# Track results
successful_uploads = []
failed_uploads = []
upload_results = {
    'total': len(artist_records),
    'successful': 0,
    'failed': 0,
    'errors': []
}

# Upload each artist with a small delay to avoid overwhelming the API
for i, artist_data in enumerate(artist_records, 1):
    artist_name = artist_data.get('artist_name')
    
    logger.info(f"Uploading artist {i}/{len(artist_records)}: {artist_name}")
    
    result = create_artist(artist_data)
    
    if result:
        successful_uploads.append(artist_name)
        upload_results['successful'] += 1
    else:
        failed_uploads.append(artist_name)
        upload_results['failed'] += 1
        upload_results['errors'].append(f"Failed to upload: {artist_name}")
    
    # Small delay to avoid rate limiting (adjust as needed)
    time.sleep(0.5)

# Display results summary
print("\n" + "="*60)
print("UPLOAD SUMMARY")
print("="*60)
print(f"Total artists processed: {upload_results['total']}")
print(f"Successful uploads: {upload_results['successful']}")
print(f"Failed uploads: {upload_results['failed']}")
print(f"Success rate: {(upload_results['successful']/upload_results['total']*100):.2f}%")

if failed_uploads:
    print(f"\nFailed artists ({len(failed_uploads)}):")
    for artist in failed_uploads:
        print(f"  - {artist}")

logger.info("Artist upload process completed")
# Out:
# 2025-10-23 10:04:00,871 - INFO - Starting artist upload process...
# 2025-10-23 10:04:00,873 - INFO - Uploading artist 1/279: 67 Inc
# 2025-10-23 10:04:01,384 - INFO - Successfully created artist: 67 Inc
# 2025-10-23 10:04:01,885 - INFO - Uploading artist 2/279: 83 Oranges
# 2025-10-23 10:04:02,411 - INFO - Successfully created artist: 83 Oranges
# 2025-10-23 10:04:02,917 - INFO - Uploading artist 3/279: Adam Graff
# 2025-10-23 10:04:03,387 - INFO - Successfully created artist: Adam Graff
# 2025-10-23 10:04:03,893 - INFO - Uploading artist 4/279: Aley Wild
# 2025-10-23 10:04:04,368 - INFO - Successfully created artist: Aley Wild
# 2025-10-23 10:04:04,870 - INFO - Uploading artist 5/279: Alice Straker
# 2025-10-23 10:04:05,390 - INFO - Successfully created artist: Alice Straker
# 2025-10-23 10:04:05,893 - INFO - Uploading artist 6/279: Alisa Galitsyna
# 2025-10-23 10:04:06,394 - INFO - Successfully created artist: Alisa Galitsyna
# 2025-10-23 10:04:06,901 - INFO - Uploading artist 7/279: Amanda Adam
# 2025-10-23 10:04:07,403 - INFO - Successfully created artist: Amanda Adam
# 2025-10-23 10:04:07,914 - INFO - Uploading artist 8/279: Amy Hastings
# 2025-10-23 10:04:08,462 - INFO - Successfully created artist: Amy Hastings
# 2025-10-23 10:04:08,967 - INFO - Uploading artist 9/279: Ana Jaks
# 2025-10-23 10:04:09,439 - INFO - Successfully created artist: Ana Jaks
# 2025-10-23 10:04:09,942 - INFO - Uploading artist 10/279: Ana Rut Bre
# 2025-10-23 10:04:10,416 - INFO - Successfully created artist: Ana Rut Bre
# 2025-10-23 10:04:10,920 - INFO - Uploading artist 11/279: Anek
# 2025-10-23 10:04:11,426 - INFO - Successfully created artist: Anek
# 2025-10-23 10:04:11,933 - INFO - Uploading artist 12/279: Ani Vidotto
# 2025-10-23 10:04:12,408 - INFO - Successfully created artist: Ani Vidotto
# 2025-10-23 10:04:12,913 - INFO - Uploading artist 13/279: Anna Mainz
# 2025-10-23 10:04:13,416 - INFO - Successfully created artist: Anna Mainz
# 2025-10-23 10:04:13,920 - INFO - Uploading artist 14/279: Anna Schmidt
# 2025-10-23 10:04:14,383 - INFO - Successfully created artist: Anna Schmidt
# 2025-10-23 10:04:14,889 - INFO - Uploading artist 15/279: Anthony Peters
# 2025-10-23 10:04:15,388 - INFO - Successfully created artist: Anthony Peters
# 2025-10-23 10:04:15,889 - INFO - Uploading artist 16/279: Anthony Peters
# 2025-10-23 10:04:16,438 - INFO - Successfully created artist: Anthony Peters
# 2025-10-23 10:04:16,941 - INFO - Uploading artist 17/279: Artist Named Nobody
# 2025-10-23 10:04:17,406 - INFO - Successfully created artist: Artist Named Nobody
# 2025-10-23 10:04:17,913 - INFO - Uploading artist 18/279: Arty Guava
# 2025-10-23 10:04:18,425 - INFO - Successfully created artist: Arty Guava
# 2025-10-23 10:04:18,926 - INFO - Uploading artist 19/279: Aster
# 2025-10-23 10:04:19,363 - INFO - Successfully created artist: Aster
# 2025-10-23 10:04:19,869 - INFO - Uploading artist 20/279: Asteronyme
# 2025-10-23 10:04:20,301 - INFO - Successfully created artist: Asteronyme
# 2025-10-23 10:04:20,807 - INFO - Uploading artist 21/279: Basil & Ford
# 2025-10-23 10:04:21,291 - INFO - Successfully created artist: Basil & Ford
# 2025-10-23 10:04:21,797 - INFO - Uploading artist 22/279: Becca Boyce
# 2025-10-23 10:04:22,263 - INFO - Successfully created artist: Becca Boyce
# 2025-10-23 10:04:22,769 - INFO - Uploading artist 23/279: Becca Who
# 2025-10-23 10:04:23,200 - INFO - Successfully created artist: Becca Who
# 2025-10-23 10:04:23,707 - INFO - Uploading artist 24/279: Becks Norf Design
# 2025-10-23 10:04:24,175 - INFO - Successfully created artist: Becks Norf Design
# 2025-10-23 10:04:24,682 - INFO - Uploading artist 25/279: Ben Rothery
# 2025-10-23 10:04:25,181 - INFO - Successfully created artist: Ben Rothery
# 2025-10-23 10:04:25,687 - INFO - Uploading artist 26/279: Bethany Young
# 2025-10-23 10:04:26,177 - INFO - Successfully created artist: Bethany Young
# 2025-10-23 10:04:26,679 - INFO - Uploading artist 27/279: Bianca Green
# 2025-10-23 10:04:27,148 - INFO - Successfully created artist: Bianca Green
# 2025-10-23 10:04:27,654 - INFO - Uploading artist 28/279: Billy The Kid
# 2025-10-23 10:04:28,167 - INFO - Successfully created artist: Billy The Kid
# 2025-10-23 10:04:28,669 - INFO - Uploading artist 29/279: Bo Lundberg
# 2025-10-23 10:04:29,157 - INFO - Successfully created artist: Bo Lundberg
# 2025-10-23 10:04:29,659 - INFO - Uploading artist 30/279: Bob & Eve
# 2025-10-23 10:04:30,141 - INFO - Successfully created artist: Bob & Eve
# 2025-10-23 10:04:30,647 - INFO - Uploading artist 31/279: Caitlin Keegan
# 2025-10-23 10:04:31,156 - INFO - Successfully created artist: Caitlin Keegan
# 2025-10-23 10:04:31,657 - INFO - Uploading artist 32/279: Caitlin Park
# 2025-10-23 10:04:32,154 - INFO - Successfully created artist: Caitlin Park
# 2025-10-23 10:04:32,660 - INFO - Uploading artist 33/279: Capricorn Press
# 2025-10-23 10:04:33,092 - INFO - Successfully created artist: Capricorn Press
# 2025-10-23 10:04:33,598 - INFO - Uploading artist 34/279: Carolin Loebbert
# 2025-10-23 10:04:34,068 - INFO - Successfully created artist: Carolin Loebbert
# 2025-10-23 10:04:34,574 - INFO - Uploading artist 35/279: Cat Coquillette
# 2025-10-23 10:04:35,070 - INFO - Successfully created artist: Cat Coquillette
# 2025-10-23 10:04:35,580 - INFO - Uploading artist 36/279: Catford Creative
# 2025-10-23 10:04:36,026 - INFO - Successfully created artist: Catford Creative
# 2025-10-23 10:04:36,532 - INFO - Uploading artist 37/279: Charlie Taylor
# 2025-10-23 10:04:37,000 - INFO - Successfully created artist: Charlie Taylor
# 2025-10-23 10:04:37,502 - INFO - Uploading artist 38/279: Christina Hagerfors
# 2025-10-23 10:04:37,971 - INFO - Successfully created artist: Christina Hagerfors
# 2025-10-23 10:04:38,478 - INFO - Uploading artist 39/279: Coco de Paris
# 2025-10-23 10:04:38,948 - INFO - Successfully created artist: Coco de Paris
# 2025-10-23 10:04:39,451 - INFO - Uploading artist 40/279: Coit Creative
# 2025-10-23 10:04:39,937 - INFO - Successfully created artist: Coit Creative
# 2025-10-23 10:04:40,444 - INFO - Uploading artist 41/279: Colour TV
# 2025-10-23 10:04:40,916 - INFO - Successfully created artist: Colour TV
# 2025-10-23 10:04:41,422 - INFO - Uploading artist 42/279: Crayon Studio
# 2025-10-23 10:04:41,916 - INFO - Successfully created artist: Crayon Studio
# 2025-10-23 10:04:42,422 - INFO - Uploading artist 43/279: Dale Edwin Murray
# 2025-10-23 10:04:42,882 - INFO - Successfully created artist: Dale Edwin Murray
# 2025-10-23 10:04:43,384 - INFO - Uploading artist 44/279: Dan Hobday
# 2025-10-23 10:04:43,897 - INFO - Successfully created artist: Dan Hobday
# 2025-10-23 10:04:44,404 - INFO - Uploading artist 45/279: Daniel Battams
# 2025-10-23 10:04:44,928 - INFO - Successfully created artist: Daniel Battams
# 2025-10-23 10:04:45,429 - INFO - Uploading artist 46/279: Daniel Haskett
# 2025-10-23 10:04:45,885 - INFO - Successfully created artist: Daniel Haskett
# 2025-10-23 10:04:46,389 - INFO - Uploading artist 47/279: Darcie Olley
# 2025-10-23 10:04:46,927 - INFO - Successfully created artist: Darcie Olley
# 2025-10-23 10:04:47,430 - INFO - Uploading artist 48/279: Deltanova
# 2025-10-23 10:04:48,025 - INFO - Successfully created artist: Deltanova
# 2025-10-23 10:04:48,534 - INFO - Uploading artist 49/279: Dicky Bird
# 2025-10-23 10:04:49,000 - INFO - Successfully created artist: Dicky Bird
# 2025-10-23 10:04:49,506 - INFO - Uploading artist 50/279: Dieter Braun
# 2025-10-23 10:04:50,017 - INFO - Successfully created artist: Dieter Braun
# 2025-10-23 10:04:50,526 - INFO - Uploading artist 51/279: Don't Grow Up
# 2025-10-23 10:04:51,019 - INFO - Successfully created artist: Don't Grow Up
# 2025-10-23 10:04:51,521 - INFO - Uploading artist 52/279: Doodle Moo
# 2025-10-23 10:04:51,996 - INFO - Successfully created artist: Doodle Moo
# 2025-10-23 10:04:52,503 - INFO - Uploading artist 53/279: Doodle by Meg
# 2025-10-23 10:04:52,958 - INFO - Successfully created artist: Doodle by Meg
# 2025-10-23 10:04:53,460 - INFO - Uploading artist 54/279: Dorothy
# 2025-10-23 10:04:53,953 - INFO - Successfully created artist: Dorothy
# 2025-10-23 10:04:54,461 - INFO - Uploading artist 55/279: Double Merrick
# 2025-10-23 10:04:54,948 - INFO - Successfully created artist: Double Merrick
# 2025-10-23 10:04:55,455 - INFO - Uploading artist 56/279: Dreamy Me
# 2025-10-23 10:04:55,950 - INFO - Successfully created artist: Dreamy Me
# 2025-10-23 10:04:56,453 - INFO - Uploading artist 57/279: EEP Design
# 2025-10-23 10:04:56,961 - INFO - Successfully created artist: EEP Design
# 2025-10-23 10:04:57,467 - INFO - Uploading artist 58/279: East London Print House
# 2025-10-23 10:04:57,931 - INFO - Successfully created artist: East London Print House
# 2025-10-23 10:04:58,437 - INFO - Uploading artist 59/279: Ec Mazur
# 2025-10-23 10:04:58,901 - INFO - Successfully created artist: Ec Mazur
# 2025-10-23 10:04:59,407 - INFO - Uploading artist 60/279: El Famoso
# 2025-10-23 10:04:59,917 - INFO - Successfully created artist: El Famoso
# 2025-10-23 10:05:00,420 - INFO - Uploading artist 61/279: Elena Boils
# 2025-10-23 10:05:00,919 - INFO - Successfully created artist: Elena Boils
# 2025-10-23 10:05:01,425 - INFO - Uploading artist 62/279: Emily Powell
# 2025-10-23 10:05:01,946 - INFO - Successfully created artist: Emily Powell
# 2025-10-23 10:05:02,452 - INFO - Uploading artist 63/279: Emmy Lupin Studio
# 2025-10-23 10:05:02,923 - INFO - Successfully created artist: Emmy Lupin Studio
# 2025-10-23 10:05:03,433 - INFO - Uploading artist 64/279: Eve Print Studio
# 2025-10-23 10:05:03,917 - INFO - Successfully created artist: Eve Print Studio
# 2025-10-23 10:05:04,422 - INFO - Uploading artist 65/279: Exquisite Paradox
# 2025-10-23 10:05:04,911 - INFO - Successfully created artist: Exquisite Paradox
# 2025-10-23 10:05:05,418 - INFO - Uploading artist 66/279: Eye for London
# 2025-10-23 10:05:05,924 - INFO - Successfully created artist: Eye for London
# 2025-10-23 10:05:06,429 - INFO - Uploading artist 67/279: Fan Club
# 2025-10-23 10:05:06,934 - INFO - Successfully created artist: Fan Club
# 2025-10-23 10:05:07,440 - INFO - Uploading artist 68/279: Fiona Watson
# 2025-10-23 10:05:07,868 - INFO - Successfully created artist: Fiona Watson
# 2025-10-23 10:05:08,374 - INFO - Uploading artist 69/279: Flood Gallery
# 2025-10-23 10:05:08,862 - INFO - Successfully created artist: Flood Gallery
# 2025-10-23 10:05:09,367 - INFO - Uploading artist 70/279: Florent Bodart
# 2025-10-23 10:05:09,817 - INFO - Successfully created artist: Florent Bodart
# 2025-10-23 10:05:10,324 - INFO - Uploading artist 71/279: Flower Love Child
# 2025-10-23 10:05:10,797 - INFO - Successfully created artist: Flower Love Child
# 2025-10-23 10:05:11,303 - INFO - Uploading artist 72/279: Fox and Velvet
# 2025-10-23 10:05:11,736 - INFO - Successfully created artist: Fox and Velvet
# 2025-10-23 10:05:12,242 - INFO - Uploading artist 73/279: Frame Only
# 2025-10-23 10:05:12,707 - INFO - Successfully created artist: Frame Only
# 2025-10-23 10:05:13,210 - INFO - Uploading artist 74/279: Frances Collett
# 2025-10-23 10:05:13,679 - INFO - Successfully created artist: Frances Collett
# 2025-10-23 10:05:14,185 - INFO - Uploading artist 75/279: Francesca Iannaccone
# 2025-10-23 10:05:14,656 - INFO - Successfully created artist: Francesca Iannaccone
# 2025-10-23 10:05:15,163 - INFO - Uploading artist 76/279: Frank Moth
# 2025-10-23 10:05:15,690 - INFO - Successfully created artist: Frank Moth
# 2025-10-23 10:05:16,196 - INFO - Uploading artist 77/279: Frankk Studio
# 2025-10-23 10:05:16,644 - INFO - Successfully created artist: Frankk Studio
# 2025-10-23 10:05:17,150 - INFO - Uploading artist 78/279: Freya MacPhail
# 2025-10-23 10:05:17,616 - INFO - Successfully created artist: Freya MacPhail
# 2025-10-23 10:05:18,127 - INFO - Uploading artist 79/279: GS Print Shoppe
# 2025-10-23 10:05:18,586 - INFO - Successfully created artist: GS Print Shoppe
# 2025-10-23 10:05:19,092 - INFO - Uploading artist 80/279: Gal+Goose
# 2025-10-23 10:05:19,579 - INFO - Successfully created artist: Gal+Goose
# 2025-10-23 10:05:20,086 - INFO - Uploading artist 81/279: Garima Dhawan
# 2025-10-23 10:05:20,558 - INFO - Successfully created artist: Garima Dhawan
# 2025-10-23 10:05:21,061 - INFO - Uploading artist 82/279: Golden Daze
# 2025-10-23 10:05:21,540 - INFO - Successfully created artist: Golden Daze
# 2025-10-23 10:05:22,042 - INFO - Uploading artist 83/279: Hali Igwelaezoh
# 2025-10-23 10:05:22,541 - INFO - Successfully created artist: Hali Igwelaezoh
# 2025-10-23 10:05:23,043 - INFO - Uploading artist 84/279: Hand Jazz
# 2025-10-23 10:05:23,524 - INFO - Successfully created artist: Hand Jazz
# 2025-10-23 10:05:24,031 - INFO - Uploading artist 85/279: Hanna Melin
# 2025-10-23 10:05:24,517 - INFO - Successfully created artist: Hanna Melin
# 2025-10-23 10:05:25,021 - INFO - Uploading artist 86/279: Hannah Gilson
# 2025-10-23 10:05:25,488 - INFO - Successfully created artist: Hannah Gilson
# 2025-10-23 10:05:25,994 - INFO - Uploading artist 87/279: Hello Bonjour
# 2025-10-23 10:05:26,477 - INFO - Successfully created artist: Hello Bonjour
# 2025-10-23 10:05:26,980 - INFO - Uploading artist 88/279: Herald Black
# 2025-10-23 10:05:27,465 - INFO - Successfully created artist: Herald Black
# 2025-10-23 10:05:27,973 - INFO - Uploading artist 89/279: HollieGraphik
# 2025-10-23 10:05:28,438 - INFO - Successfully created artist: HollieGraphik
# 2025-10-23 10:05:28,945 - INFO - Uploading artist 90/279: Honey Island Studio
# 2025-10-23 10:05:29,409 - INFO - Successfully created artist: Honey Island Studio
# 2025-10-23 10:05:29,912 - INFO - Uploading artist 91/279: Honeymoon Hotel
# 2025-10-23 10:05:30,383 - INFO - Successfully created artist: Honeymoon Hotel
# 2025-10-23 10:05:30,891 - INFO - Uploading artist 92/279: I Ended Up Here
# 2025-10-23 10:05:31,361 - INFO - Successfully created artist: I Ended Up Here
# 2025-10-23 10:05:31,867 - INFO - Uploading artist 93/279: Ian Stevenson
# 2025-10-23 10:05:32,373 - INFO - Successfully created artist: Ian Stevenson
# 2025-10-23 10:05:32,879 - INFO - Uploading artist 94/279: Illustrated by Charlie
# 2025-10-23 10:05:33,345 - INFO - Successfully created artist: Illustrated by Charlie
# 2025-10-23 10:05:33,852 - INFO - Uploading artist 95/279: Illustrated by Weezy
# 2025-10-23 10:05:34,318 - INFO - Successfully created artist: Illustrated by Weezy
# 2025-10-23 10:05:34,824 - INFO - Uploading artist 96/279: Indieprints
# 2025-10-23 10:05:35,316 - INFO - Successfully created artist: Indieprints
# 2025-10-23 10:05:35,822 - INFO - Uploading artist 97/279: Ingrid Beddoes
# 2025-10-23 10:05:36,307 - INFO - Successfully created artist: Ingrid Beddoes
# 2025-10-23 10:05:36,815 - INFO - Uploading artist 98/279: Ink OnK
# 2025-10-23 10:05:37,317 - INFO - Successfully created artist: Ink OnK
# 2025-10-23 10:05:37,823 - INFO - Uploading artist 99/279: Ink Tally
# 2025-10-23 10:05:38,303 - INFO - Successfully created artist: Ink Tally
# 2025-10-23 10:05:38,805 - INFO - Uploading artist 100/279: Inoui
# 2025-10-23 10:05:39,281 - INFO - Successfully created artist: Inoui
# 2025-10-23 10:05:39,789 - INFO - Uploading artist 101/279: Iris Lehnhardt
# 2025-10-23 10:05:40,275 - INFO - Successfully created artist: Iris Lehnhardt
# 2025-10-23 10:05:40,781 - INFO - Uploading artist 102/279: Jack Sinnot
# 2025-10-23 10:05:41,257 - INFO - Successfully created artist: Jack Sinnot
# 2025-10-23 10:05:41,764 - INFO - Uploading artist 103/279: Jack Sinnott
# 2025-10-23 10:05:42,249 - INFO - Successfully created artist: Jack Sinnott
# 2025-10-23 10:05:42,755 - INFO - Uploading artist 104/279: Jacqueline Colley
# 2025-10-23 10:05:43,234 - INFO - Successfully created artist: Jacqueline Colley
# 2025-10-23 10:05:43,740 - INFO - Uploading artist 105/279: James Brown
# 2025-10-23 10:05:44,219 - INFO - Successfully created artist: James Brown
# 2025-10-23 10:05:44,725 - INFO - Uploading artist 106/279: James Campbell Taylor
# 2025-10-23 10:05:45,237 - INFO - Successfully created artist: James Campbell Taylor
# 2025-10-23 10:05:45,744 - INFO - Uploading artist 107/279: Jane Smith
# 2025-10-23 10:05:46,216 - INFO - Successfully created artist: Jane Smith
# 2025-10-23 10:05:46,722 - INFO - Uploading artist 108/279: Jason Ratliff
# 2025-10-23 10:05:47,187 - INFO - Successfully created artist: Jason Ratliff
# 2025-10-23 10:05:47,693 - INFO - Uploading artist 109/279: Jay Fleck
# 2025-10-23 10:05:48,170 - INFO - Successfully created artist: Jay Fleck
# 2025-10-23 10:05:48,672 - INFO - Uploading artist 110/279: Jayson Lilley
# 2025-10-23 10:05:49,128 - INFO - Successfully created artist: Jayson Lilley
# 2025-10-23 10:05:49,634 - INFO - Uploading artist 111/279: Jazmine Joye
# 2025-10-23 10:05:50,103 - INFO - Successfully created artist: Jazmine Joye
# 2025-10-23 10:05:50,612 - INFO - Uploading artist 112/279: Jazzberry Blue
# 2025-10-23 10:05:51,095 - INFO - Successfully created artist: Jazzberry Blue
# 2025-10-23 10:05:51,602 - INFO - Uploading artist 113/279: Jess Wilson
# 2025-10-23 10:05:52,101 - INFO - Successfully created artist: Jess Wilson
# 2025-10-23 10:05:52,607 - INFO - Uploading artist 114/279: Joanna Mudrowska
# 2025-10-23 10:05:53,086 - INFO - Successfully created artist: Joanna Mudrowska
# 2025-10-23 10:05:53,588 - INFO - Uploading artist 115/279: Johanna von Holst
# 2025-10-23 10:05:54,083 - INFO - Successfully created artist: Johanna von Holst
# 2025-10-23 10:05:54,585 - INFO - Uploading artist 116/279: Jorgen Hansson
# 2025-10-23 10:05:55,073 - INFO - Successfully created artist: Jorgen Hansson
# 2025-10-23 10:05:55,577 - INFO - Uploading artist 117/279: Judy Andrews
# 2025-10-23 10:05:56,048 - INFO - Successfully created artist: Judy Andrews
# 2025-10-23 10:05:56,555 - INFO - Uploading artist 118/279: Julia Noble
# 2025-10-23 10:05:57,051 - INFO - Successfully created artist: Julia Noble
# 2025-10-23 10:05:57,552 - INFO - Uploading artist 119/279: Julia Ockert
# 2025-10-23 10:05:58,014 - INFO - Successfully created artist: Julia Ockert
# 2025-10-23 10:05:58,521 - INFO - Uploading artist 120/279: Julia Walck
# 2025-10-23 10:05:58,996 - INFO - Successfully created artist: Julia Walck
# 2025-10-23 10:05:59,501 - INFO - Uploading artist 121/279: Julie Lavender
# 2025-10-23 10:05:59,996 - INFO - Successfully created artist: Julie Lavender
# 2025-10-23 10:06:00,503 - INFO - Uploading artist 122/279: KaloolaJay Studio
# 2025-10-23 10:06:01,001 - INFO - Successfully created artist: KaloolaJay Studio
# 2025-10-23 10:06:01,507 - INFO - Uploading artist 123/279: Karin Akesson
# 2025-10-23 10:06:01,960 - INFO - Successfully created artist: Karin Akesson
# 2025-10-23 10:06:02,466 - INFO - Uploading artist 124/279: Kartika Paramita
# 2025-10-23 10:06:02,923 - INFO - Successfully created artist: Kartika Paramita
# 2025-10-23 10:06:03,431 - INFO - Uploading artist 125/279: Katy Edelsten
# 2025-10-23 10:06:03,906 - INFO - Successfully created artist: Katy Edelsten
# 2025-10-23 10:06:04,412 - INFO - Uploading artist 126/279: Katy Smail
# 2025-10-23 10:06:04,865 - INFO - Successfully created artist: Katy Smail
# 2025-10-23 10:06:05,371 - INFO - Uploading artist 127/279: Katy Welsh
# 2025-10-23 10:06:05,838 - INFO - Successfully created artist: Katy Welsh
# 2025-10-23 10:06:06,340 - INFO - Uploading artist 128/279: Kavel Rafferty
# 2025-10-23 10:06:06,848 - INFO - Successfully created artist: Kavel Rafferty
# 2025-10-23 10:06:07,357 - INFO - Uploading artist 129/279: Keeler & Sidaway
# 2025-10-23 10:06:07,804 - INFO - Successfully created artist: Keeler & Sidaway
# 2025-10-23 10:06:08,311 - INFO - Uploading artist 130/279: Keren Parmley
# 2025-10-23 10:06:08,784 - INFO - Successfully created artist: Keren Parmley
# 2025-10-23 10:06:09,293 - INFO - Uploading artist 131/279: Kid of the Village
# 2025-10-23 10:06:09,794 - INFO - Successfully created artist: Kid of the Village
# 2025-10-23 10:06:10,296 - INFO - Uploading artist 132/279: Kubistika
# 2025-10-23 10:06:10,786 - INFO - Successfully created artist: Kubistika
# 2025-10-23 10:06:11,289 - INFO - Uploading artist 133/279: Laura Knight
# 2025-10-23 10:06:11,761 - INFO - Successfully created artist: Laura Knight
# 2025-10-23 10:06:12,265 - INFO - Uploading artist 134/279: Laura Page
# 2025-10-23 10:06:12,728 - INFO - Successfully created artist: Laura Page
# 2025-10-23 10:06:13,233 - INFO - Uploading artist 135/279: Layover Art
# 2025-10-23 10:06:13,703 - INFO - Successfully created artist: Layover Art
# 2025-10-23 10:06:14,211 - INFO - Uploading artist 136/279: Leanne Simpson
# 2025-10-23 10:06:14,686 - INFO - Successfully created artist: Leanne Simpson
# 2025-10-23 10:06:15,187 - INFO - Uploading artist 137/279: Lemon Fee
# 2025-10-23 10:06:15,688 - INFO - Successfully created artist: Lemon Fee
# 2025-10-23 10:06:16,194 - INFO - Uploading artist 138/279: Limbo and Ginger
# 2025-10-23 10:06:16,716 - INFO - Successfully created artist: Limbo and Ginger
# 2025-10-23 10:06:17,222 - INFO - Uploading artist 139/279: Linda Gobeta
# 2025-10-23 10:06:17,685 - INFO - Successfully created artist: Linda Gobeta
# 2025-10-23 10:06:18,187 - INFO - Uploading artist 140/279: Little Lark
# 2025-10-23 10:06:18,663 - INFO - Successfully created artist: Little Lark
# 2025-10-23 10:06:19,173 - INFO - Uploading artist 141/279: Lizzie Prestt
# 2025-10-23 10:06:19,678 - INFO - Successfully created artist: Lizzie Prestt
# 2025-10-23 10:06:20,184 - INFO - Uploading artist 142/279: Lollipop Studio
# 2025-10-23 10:06:20,656 - INFO - Successfully created artist: Lollipop Studio
# 2025-10-23 10:06:21,162 - INFO - Uploading artist 143/279: Lora O'Callaghan
# 2025-10-23 10:06:21,647 - INFO - Successfully created artist: Lora O'Callaghan
# 2025-10-23 10:06:22,153 - INFO - Uploading artist 144/279: Lucie Sheridan
# 2025-10-23 10:06:22,644 - INFO - Successfully created artist: Lucie Sheridan
# 2025-10-23 10:06:23,147 - INFO - Uploading artist 145/279: Lucky Budgie
# 2025-10-23 10:06:23,937 - INFO - Successfully created artist: Lucky Budgie
# 2025-10-23 10:06:24,443 - INFO - Uploading artist 146/279: Lucy Merriman
# 2025-10-23 10:06:24,906 - INFO - Successfully created artist: Lucy Merriman
# 2025-10-23 10:06:25,412 - INFO - Uploading artist 147/279: Lucy Muss
# 2025-10-23 10:06:25,898 - INFO - Successfully created artist: Lucy Muss
# 2025-10-23 10:06:26,406 - INFO - Uploading artist 148/279: Luxe Poster Co
# 2025-10-23 10:06:26,915 - INFO - Successfully created artist: Luxe Poster Co
# 2025-10-23 10:06:27,420 - INFO - Uploading artist 149/279: Magnus Myhre
# 2025-10-23 10:06:27,887 - INFO - Successfully created artist: Magnus Myhre
# 2025-10-23 10:06:28,393 - INFO - Uploading artist 150/279: Mahin Hussain
# 2025-10-23 10:06:28,876 - INFO - Successfully created artist: Mahin Hussain
# 2025-10-23 10:06:29,378 - INFO - Uploading artist 151/279: Marcus Walters
# 2025-10-23 10:06:29,849 - INFO - Successfully created artist: Marcus Walters
# 2025-10-23 10:06:30,352 - INFO - Uploading artist 152/279: Mareike Boehmer
# 2025-10-23 10:06:30,783 - INFO - Successfully created artist: Mareike Boehmer
# 2025-10-23 10:06:31,289 - INFO - Uploading artist 153/279: Mariery Young
# 2025-10-23 10:06:31,773 - INFO - Successfully created artist: Mariery Young
# 2025-10-23 10:06:32,279 - INFO - Uploading artist 154/279: Marina Ester Castaldo
# 2025-10-23 10:06:32,766 - INFO - Successfully created artist: Marina Ester Castaldo
# 2025-10-23 10:06:33,276 - INFO - Uploading artist 155/279: Mark Harrison
# 2025-10-23 10:06:33,744 - INFO - Successfully created artist: Mark Harrison
# 2025-10-23 10:06:34,249 - INFO - Uploading artist 156/279: Matchbox Labels
# 2025-10-23 10:06:34,727 - INFO - Successfully created artist: Matchbox Labels
# 2025-10-23 10:06:35,232 - INFO - Uploading artist 157/279: Melissa North
# 2025-10-23 10:06:35,753 - INFO - Successfully created artist: Melissa North
# 2025-10-23 10:06:36,257 - INFO - Uploading artist 158/279: Miho Art Studio
# 2025-10-23 10:06:36,735 - INFO - Successfully created artist: Miho Art Studio
# 2025-10-23 10:06:37,242 - INFO - Uploading artist 159/279: Mike Hall
# 2025-10-23 10:06:37,692 - INFO - Successfully created artist: Mike Hall
# 2025-10-23 10:06:38,198 - INFO - Uploading artist 160/279: Min Pin
# 2025-10-23 10:06:38,695 - INFO - Successfully created artist: Min Pin
# 2025-10-23 10:06:39,198 - INFO - Uploading artist 161/279: Miscellaneous
# 2025-10-23 10:06:39,717 - INFO - Successfully created artist: Miscellaneous
# 2025-10-23 10:06:40,219 - INFO - Uploading artist 162/279: Mother & Sun Studio
# 2025-10-23 10:06:40,689 - INFO - Successfully created artist: Mother & Sun Studio
# 2025-10-23 10:06:41,192 - INFO - Uploading artist 163/279: MsGonzalez
# 2025-10-23 10:06:41,686 - INFO - Successfully created artist: MsGonzalez
# 2025-10-23 10:06:42,193 - INFO - Uploading artist 164/279: Nancy McKie
# 2025-10-23 10:06:42,673 - INFO - Successfully created artist: Nancy McKie
# 2025-10-23 10:06:43,179 - INFO - Uploading artist 165/279: Natalie Cass
# 2025-10-23 10:06:43,644 - INFO - Successfully created artist: Natalie Cass
# 2025-10-23 10:06:44,151 - INFO - Uploading artist 166/279: Nia Beynon
# 2025-10-23 10:06:44,620 - INFO - Successfully created artist: Nia Beynon
# 2025-10-23 10:06:45,125 - INFO - Uploading artist 167/279: Nice Draws
# 2025-10-23 10:06:45,688 - INFO - Successfully created artist: Nice Draws
# 2025-10-23 10:06:46,193 - INFO - Uploading artist 168/279: Nichola Cowdery
# 2025-10-23 10:06:46,687 - INFO - Successfully created artist: Nichola Cowdery
# 2025-10-23 10:06:47,194 - INFO - Uploading artist 169/279: North 6 Graphic Design
# 2025-10-23 10:06:47,638 - INFO - Successfully created artist: North 6 Graphic Design
# 2025-10-23 10:06:48,144 - INFO - Uploading artist 170/279: OHH DEER
# 2025-10-23 10:06:48,667 - INFO - Successfully created artist: OHH DEER
# 2025-10-23 10:06:49,173 - INFO - Uploading artist 171/279: OKNO
# 2025-10-23 10:06:49,666 - INFO - Successfully created artist: OKNO
# 2025-10-23 10:06:50,175 - INFO - Uploading artist 172/279: Oh Fine! Art
# 2025-10-23 10:06:50,646 - INFO - Successfully created artist: Oh Fine! Art
# 2025-10-23 10:06:51,152 - INFO - Uploading artist 173/279: Olivia Axson
# 2025-10-23 10:06:51,672 - INFO - Successfully created artist: Olivia Axson
# 2025-10-23 10:06:52,174 - INFO - Uploading artist 174/279: One Gog
# 2025-10-23 10:06:52,668 - INFO - Successfully created artist: One Gog
# 2025-10-23 10:06:53,174 - INFO - Uploading artist 175/279: Oshe POP!
# 2025-10-23 10:06:53,666 - INFO - Successfully created artist: Oshe POP!
# 2025-10-23 10:06:54,170 - INFO - Uploading artist 176/279: Parrott Paints
# 2025-10-23 10:06:54,657 - INFO - Successfully created artist: Parrott Paints
# 2025-10-23 10:06:55,159 - INFO - Uploading artist 177/279: Paul Hamilton
# 2025-10-23 10:06:55,637 - INFO - Successfully created artist: Paul Hamilton
# 2025-10-23 10:06:56,140 - INFO - Uploading artist 178/279: Philip Sheffield
# 2025-10-23 10:06:56,599 - INFO - Successfully created artist: Philip Sheffield
# 2025-10-23 10:06:57,106 - INFO - Uploading artist 179/279: Places & Spaces Art Co
# 2025-10-23 10:06:57,581 - INFO - Successfully created artist: Places & Spaces Art Co
# 2025-10-23 10:06:58,083 - INFO - Uploading artist 180/279: Planet Patrol
# 2025-10-23 10:06:58,577 - INFO - Successfully created artist: Planet Patrol
# 2025-10-23 10:06:59,084 - INFO - Uploading artist 181/279: Poet and Painter
# 2025-10-23 10:06:59,536 - INFO - Successfully created artist: Poet and Painter
# 2025-10-23 10:07:00,037 - INFO - Uploading artist 182/279: Printer Johnson
# 2025-10-23 10:07:00,500 - INFO - Successfully created artist: Printer Johnson
# 2025-10-23 10:07:01,002 - INFO - Uploading artist 183/279: Protest Nation
# 2025-10-23 10:07:01,503 - INFO - Successfully created artist: Protest Nation
# 2025-10-23 10:07:02,006 - INFO - Uploading artist 184/279: Pulp Brother
# 2025-10-23 10:07:02,467 - INFO - Successfully created artist: Pulp Brother
# 2025-10-23 10:07:02,974 - INFO - Uploading artist 185/279: Rachel Lee
# 2025-10-23 10:07:03,467 - INFO - Successfully created artist: Rachel Lee
# 2025-10-23 10:07:03,973 - INFO - Uploading artist 186/279: Rachel Locke
# 2025-10-23 10:07:04,445 - INFO - Successfully created artist: Rachel Locke
# 2025-10-23 10:07:04,952 - INFO - Uploading artist 187/279: Rafael Farias
# 2025-10-23 10:07:05,407 - INFO - Successfully created artist: Rafael Farias
# 2025-10-23 10:07:05,912 - INFO - Uploading artist 188/279: Rawhide
# 2025-10-23 10:07:06,393 - INFO - Successfully created artist: Rawhide
# 2025-10-23 10:07:06,898 - INFO - Uploading artist 189/279: Rebecca Morcombe Young
# 2025-10-23 10:07:07,415 - INFO - Successfully created artist: Rebecca Morcombe Young
# 2025-10-23 10:07:07,919 - INFO - Uploading artist 190/279: Rebecca Strickson
# 2025-10-23 10:07:08,365 - INFO - Successfully created artist: Rebecca Strickson
# 2025-10-23 10:07:08,871 - INFO - Uploading artist 191/279: Red Faces Prints
# 2025-10-23 10:07:09,347 - INFO - Successfully created artist: Red Faces Prints
# 2025-10-23 10:07:09,855 - INFO - Uploading artist 192/279: Rhianna Marie Chan
# 2025-10-23 10:07:10,346 - INFO - Successfully created artist: Rhianna Marie Chan
# 2025-10-23 10:07:10,849 - INFO - Uploading artist 193/279: Rocket 68
# 2025-10-23 10:07:11,340 - INFO - Successfully created artist: Rocket 68
# 2025-10-23 10:07:11,842 - INFO - Uploading artist 194/279: Rocket Jack
# 2025-10-23 10:07:12,367 - INFO - Successfully created artist: Rocket Jack
# 2025-10-23 10:07:12,873 - INFO - Uploading artist 195/279: Rosi Feist
# 2025-10-23 10:07:13,338 - INFO - Successfully created artist: Rosi Feist
# 2025-10-23 10:07:13,841 - INFO - Uploading artist 196/279: Ruben Ireland
# 2025-10-23 10:07:14,373 - INFO - Successfully created artist: Ruben Ireland
# 2025-10-23 10:07:14,875 - INFO - Uploading artist 197/279: Rude
# 2025-10-23 10:07:15,362 - INFO - Successfully created artist: Rude
# 2025-10-23 10:07:15,864 - INFO - Uploading artist 198/279: SHIO
# 2025-10-23 10:07:16,357 - INFO - Successfully created artist: SHIO
# 2025-10-23 10:07:16,863 - INFO - Uploading artist 199/279: Sam Capell
# 2025-10-23 10:07:17,373 - INFO - Successfully created artist: Sam Capell
# 2025-10-23 10:07:17,879 - INFO - Uploading artist 200/279: Sammy Hearn
# 2025-10-23 10:07:18,377 - INFO - Successfully created artist: Sammy Hearn
# 2025-10-23 10:07:18,883 - INFO - Uploading artist 201/279: Sandra Poliakov
# 2025-10-23 10:07:19,356 - INFO - Successfully created artist: Sandra Poliakov
# 2025-10-23 10:07:19,862 - INFO - Uploading artist 202/279: Say It With Songs
# 2025-10-23 10:07:20,335 - INFO - Successfully created artist: Say It With Songs
# 2025-10-23 10:07:20,841 - INFO - Uploading artist 203/279: Scribbler
# 2025-10-23 10:07:21,359 - INFO - Successfully created artist: Scribbler
# 2025-10-23 10:07:21,860 - INFO - Uploading artist 204/279: Sean Butler
# 2025-10-23 10:07:22,341 - INFO - Successfully created artist: Sean Butler
# 2025-10-23 10:07:22,853 - INFO - Uploading artist 205/279: Seekprint
# 2025-10-23 10:07:23,308 - INFO - Successfully created artist: Seekprint
# 2025-10-23 10:07:23,817 - INFO - Uploading artist 206/279: Sei and Ru
# 2025-10-23 10:07:24,286 - INFO - Successfully created artist: Sei and Ru
# 2025-10-23 10:07:24,793 - INFO - Uploading artist 207/279: Seventy Tree
# 2025-10-23 10:07:25,309 - INFO - Successfully created artist: Seventy Tree
# 2025-10-23 10:07:25,819 - INFO - Uploading artist 208/279: She Snacks and Paints
# 2025-10-23 10:07:26,337 - INFO - Successfully created artist: She Snacks and Paints
# 2025-10-23 10:07:26,844 - INFO - Uploading artist 209/279: Show Me Mars
# 2025-10-23 10:07:27,355 - INFO - Successfully created artist: Show Me Mars
# 2025-10-23 10:07:27,857 - INFO - Uploading artist 210/279: Sifa Mustafa
# 2025-10-23 10:07:28,362 - INFO - Successfully created artist: Sifa Mustafa
# 2025-10-23 10:07:28,867 - INFO - Uploading artist 211/279: Simon C Page
# 2025-10-23 10:07:29,356 - INFO - Successfully created artist: Simon C Page
# 2025-10-23 10:07:29,862 - INFO - Uploading artist 212/279: SimplyExtraJordanary
# 2025-10-23 10:07:30,378 - INFO - Successfully created artist: SimplyExtraJordanary
# 2025-10-23 10:07:30,884 - INFO - Uploading artist 213/279: Sisi and Seb
# 2025-10-23 10:07:31,366 - INFO - Successfully created artist: Sisi and Seb
# 2025-10-23 10:07:31,870 - INFO - Uploading artist 214/279: Sofia Doudine
# 2025-10-23 10:07:32,385 - INFO - Successfully created artist: Sofia Doudine
# 2025-10-23 10:07:32,891 - INFO - Uploading artist 215/279: Sophia Ward
# 2025-10-23 10:07:33,384 - INFO - Successfully created artist: Sophia Ward
# 2025-10-23 10:07:33,891 - INFO - Uploading artist 216/279: Sophie Harding
# 2025-10-23 10:07:34,355 - INFO - Successfully created artist: Sophie Harding
# 2025-10-23 10:07:34,857 - INFO - Uploading artist 217/279: Sophie Ward
# 2025-10-23 10:07:35,327 - INFO - Successfully created artist: Sophie Ward
# 2025-10-23 10:07:35,833 - INFO - Uploading artist 218/279: Sshepaints
# 2025-10-23 10:07:36,363 - INFO - Successfully created artist: Sshepaints
# 2025-10-23 10:07:36,866 - INFO - Uploading artist 219/279: Stephie Cardona
# 2025-10-23 10:07:37,299 - INFO - Successfully created artist: Stephie Cardona
# 2025-10-23 10:07:37,801 - INFO - Uploading artist 220/279: Stu Is Cool
# 2025-10-23 10:07:38,295 - INFO - Successfully created artist: Stu Is Cool
# 2025-10-23 10:07:38,798 - INFO - Uploading artist 221/279: Studio Cockatoo
# 2025-10-23 10:07:39,237 - INFO - Successfully created artist: Studio Cockatoo
# 2025-10-23 10:07:39,743 - INFO - Uploading artist 222/279: Studio Eleni
# 2025-10-23 10:07:40,269 - INFO - Successfully created artist: Studio Eleni
# 2025-10-23 10:07:40,779 - INFO - Uploading artist 223/279: Studio Na.hili
# 2025-10-23 10:07:41,265 - INFO - Successfully created artist: Studio Na.hili
# 2025-10-23 10:07:41,767 - INFO - Uploading artist 224/279: Summer Du Plessis
# 2025-10-23 10:07:42,275 - INFO - Successfully created artist: Summer Du Plessis
# 2025-10-23 10:07:42,778 - INFO - Uploading artist 225/279: Summer du Plessis
# 2025-10-23 10:07:43,237 - INFO - Successfully created artist: Summer du Plessis
# 2025-10-23 10:07:43,743 - INFO - Uploading artist 226/279: Sumuyya Khader
# 2025-10-23 10:07:44,234 - INFO - Successfully created artist: Sumuyya Khader
# 2025-10-23 10:07:44,740 - INFO - Uploading artist 227/279: Sundry Society
# 2025-10-23 10:07:45,234 - INFO - Successfully created artist: Sundry Society
# 2025-10-23 10:07:45,737 - INFO - Uploading artist 228/279: Supermundane
# 2025-10-23 10:07:46,233 - INFO - Successfully created artist: Supermundane
# 2025-10-23 10:07:46,740 - INFO - Uploading artist 229/279: Susan Taylor Design
# 2025-10-23 10:07:47,211 - INFO - Successfully created artist: Susan Taylor Design
# 2025-10-23 10:07:47,713 - INFO - Uploading artist 230/279: Susana Paz
# 2025-10-23 10:07:48,196 - INFO - Successfully created artist: Susana Paz
# 2025-10-23 10:07:48,702 - INFO - Uploading artist 231/279: Susie Miller
# 2025-10-23 10:07:49,146 - INFO - Successfully created artist: Susie Miller
# 2025-10-23 10:07:49,659 - INFO - Uploading artist 232/279: Swifty Jazz
# 2025-10-23 10:07:50,179 - INFO - Successfully created artist: Swifty Jazz
# 2025-10-23 10:07:50,686 - INFO - Uploading artist 233/279: Sylvia Moritz
# 2025-10-23 10:07:51,196 - INFO - Successfully created artist: Sylvia Moritz
# 2025-10-23 10:07:51,703 - INFO - Uploading artist 234/279: Tartagain
# 2025-10-23 10:07:52,204 - INFO - Successfully created artist: Tartagain
# 2025-10-23 10:07:52,710 - INFO - Uploading artist 235/279: Telegramme Paper Co.
# 2025-10-23 10:07:53,207 - INFO - Successfully created artist: Telegramme Paper Co.
# 2025-10-23 10:07:53,715 - INFO - Uploading artist 236/279: Teresa Rego
# 2025-10-23 10:07:54,166 - INFO - Successfully created artist: Teresa Rego
# 2025-10-23 10:07:54,669 - INFO - Uploading artist 237/279: The 13 Prints
# 2025-10-23 10:07:55,158 - INFO - Successfully created artist: The 13 Prints
# 2025-10-23 10:07:55,664 - INFO - Uploading artist 238/279: The Colour Study
# 2025-10-23 10:07:56,127 - INFO - Successfully created artist: The Colour Study
# 2025-10-23 10:07:56,639 - INFO - Uploading artist 239/279: The Designers Nursery
# 2025-10-23 10:07:57,098 - INFO - Successfully created artist: The Designers Nursery
# 2025-10-23 10:07:57,605 - INFO - Uploading artist 240/279: The Dybdahl Co
# 2025-10-23 10:07:58,057 - INFO - Successfully created artist: The Dybdahl Co
# 2025-10-23 10:07:58,559 - INFO - Uploading artist 241/279: The Melomaniac
# 2025-10-23 10:07:59,120 - INFO - Successfully created artist: The Melomaniac
# 2025-10-23 10:07:59,626 - INFO - Uploading artist 242/279: The Native State
# 2025-10-23 10:08:00,095 - INFO - Successfully created artist: The Native State
# 2025-10-23 10:08:00,601 - INFO - Uploading artist 243/279: The Natural History Museum
# 2025-10-23 10:08:01,080 - INFO - Successfully created artist: The Natural History Museum
# 2025-10-23 10:08:01,584 - INFO - Uploading artist 244/279: The Pattern Press
# 2025-10-23 10:08:02,092 - INFO - Successfully created artist: The Pattern Press
# 2025-10-23 10:08:02,598 - INFO - Uploading artist 245/279: The Stereo Typist
# 2025-10-23 10:08:03,053 - INFO - Successfully created artist: The Stereo Typist
# 2025-10-23 10:08:03,556 - INFO - Uploading artist 246/279: The Violet Eclectic
# 2025-10-23 10:08:03,988 - INFO - Successfully created artist: The Violet Eclectic
# 2025-10-23 10:08:04,496 - INFO - Uploading artist 247/279: This Charming Print
# 2025-10-23 10:08:05,023 - INFO - Successfully created artist: This Charming Print
# 2025-10-23 10:08:05,530 - INFO - Uploading artist 248/279: Thoth Adan
# 2025-10-23 10:08:06,015 - INFO - Successfully created artist: Thoth Adan
# 2025-10-23 10:08:06,519 - INFO - Uploading artist 249/279: Tiffany Lynch
# 2025-10-23 10:08:07,064 - INFO - Successfully created artist: Tiffany Lynch
# 2025-10-23 10:08:07,573 - INFO - Uploading artist 250/279: Tiger Spirit Prints
# 2025-10-23 10:08:08,035 - INFO - Successfully created artist: Tiger Spirit Prints
# 2025-10-23 10:08:08,541 - INFO - Uploading artist 251/279: Tiny Riot
# 2025-10-23 10:08:09,086 - INFO - Successfully created artist: Tiny Riot
# 2025-10-23 10:08:09,594 - INFO - Uploading artist 252/279: Tom Pigeon
# 2025-10-23 10:08:10,089 - INFO - Successfully created artist: Tom Pigeon
# 2025-10-23 10:08:10,597 - INFO - Uploading artist 253/279: Tomartacus
# 2025-10-23 10:08:11,105 - INFO - Successfully created artist: Tomartacus
# 2025-10-23 10:08:11,618 - INFO - Uploading artist 254/279: Tony Green
# 2025-10-23 10:08:12,121 - INFO - Successfully created artist: Tony Green
# 2025-10-23 10:08:12,626 - INFO - Uploading artist 255/279: Tracie Andrews
# 2025-10-23 10:08:13,090 - INFO - Successfully created artist: Tracie Andrews
# 2025-10-23 10:08:13,592 - INFO - Uploading artist 256/279: Tree x Three
# 2025-10-23 10:08:14,079 - INFO - Successfully created artist: Tree x Three
# 2025-10-23 10:08:14,585 - INFO - Uploading artist 257/279: Twisted Rebel Design
# 2025-10-23 10:08:15,048 - INFO - Successfully created artist: Twisted Rebel Design
# 2025-10-23 10:08:15,552 - INFO - Uploading artist 258/279: Twisted Rebel Designs
# 2025-10-23 10:08:16,046 - INFO - Successfully created artist: Twisted Rebel Designs
# 2025-10-23 10:08:16,552 - INFO - Uploading artist 259/279: U Studio
# 2025-10-23 10:08:17,045 - INFO - Successfully created artist: U Studio
# 2025-10-23 10:08:17,551 - INFO - Uploading artist 260/279: Uncool John
# 2025-10-23 10:08:18,006 - INFO - Successfully created artist: Uncool John
# 2025-10-23 10:08:18,512 - INFO - Uploading artist 261/279: Underway Studio
# 2025-10-23 10:08:18,982 - INFO - Successfully created artist: Underway Studio
# 2025-10-23 10:08:19,489 - INFO - Uploading artist 262/279: Vertigo Artography
# 2025-10-23 10:08:19,963 - INFO - Successfully created artist: Vertigo Artography
# 2025-10-23 10:08:20,471 - INFO - Uploading artist 263/279: Vicky Langdon
# 2025-10-23 10:08:20,971 - INFO - Successfully created artist: Vicky Langdon
# 2025-10-23 10:08:21,479 - INFO - Uploading artist 264/279: Vincent Trinidad
# 2025-10-23 10:08:21,964 - INFO - Successfully created artist: Vincent Trinidad
# 2025-10-23 10:08:22,469 - INFO - Uploading artist 265/279: Vintage by Hemingway
# 2025-10-23 10:08:22,900 - INFO - Successfully created artist: Vintage by Hemingway
# 2025-10-23 10:08:23,403 - INFO - Uploading artist 266/279: Violet Studio
# 2025-10-23 10:08:23,878 - INFO - Successfully created artist: Violet Studio
# 2025-10-23 10:08:24,383 - INFO - Uploading artist 267/279: Wacka
# 2025-10-23 10:08:24,871 - INFO - Successfully created artist: Wacka
# 2025-10-23 10:08:25,377 - INFO - Uploading artist 268/279: Wall Chart
# 2025-10-23 10:08:25,845 - INFO - Successfully created artist: Wall Chart
# 2025-10-23 10:08:26,354 - INFO - Uploading artist 269/279: We Made Something Nice
# 2025-10-23 10:08:26,863 - INFO - Successfully created artist: We Made Something Nice
# 2025-10-23 10:08:27,369 - INFO - Uploading artist 270/279: Wildsuga
# 2025-10-23 10:08:27,838 - INFO - Successfully created artist: Wildsuga
# 2025-10-23 10:08:28,344 - INFO - Uploading artist 271/279: Will Clarke
# 2025-10-23 10:08:28,846 - INFO - Successfully created artist: Will Clarke
# 2025-10-23 10:08:29,354 - INFO - Uploading artist 272/279: Woah There Pickle
# 2025-10-23 10:08:29,830 - INFO - Successfully created artist: Woah There Pickle
# 2025-10-23 10:08:30,336 - INFO - Uploading artist 273/279: Wonder and Rah
# 2025-10-23 10:08:30,916 - INFO - Successfully created artist: Wonder and Rah
# 2025-10-23 10:08:31,421 - INFO - Uploading artist 274/279: Word Quirk
# 2025-10-23 10:08:31,892 - INFO - Successfully created artist: Word Quirk
# 2025-10-23 10:08:32,396 - INFO - Uploading artist 275/279: Your Local Ross
# 2025-10-23 10:08:32,825 - INFO - Successfully created artist: Your Local Ross
# 2025-10-23 10:08:33,331 - INFO - Uploading artist 276/279: apricot+birch
# 2025-10-23 10:08:33,791 - INFO - Successfully created artist: apricot+birch
# 2025-10-23 10:08:34,296 - INFO - Uploading artist 277/279: blanchouse
# 2025-10-23 10:08:34,761 - INFO - Successfully created artist: blanchouse
# 2025-10-23 10:08:35,262 - INFO - Uploading artist 278/279: cartissi
# 2025-10-23 10:08:35,749 - INFO - Successfully created artist: cartissi
# 2025-10-23 10:08:36,258 - INFO - Uploading artist 279/279: m00d
# 2025-10-23 10:08:36,764 - INFO - Successfully created artist: m00d
# 2025-10-23 10:08:37,272 - INFO - Artist upload process completed
# ============================================================
# UPLOAD SUMMARY
# ============================================================
# Total artists processed: 279
# Successful uploads: 279
# Failed uploads: 0
# Success rate: 100.00%

# %% [raw]
# ## Summary and Recommendations
#
# ### What was done:
# 1. ✅ Loaded CSV data containing artist information
# 2. ✅ Extracted unique artist names with their royalty rates
# 3. ✅ Cleaned and validated data
# 4. ✅ Mapped CSV columns to API field names:
#    - `Artist` → `artist_name`
#    - `Artist Royalty - Retail` → `artist_royalties_retail`
#    - `Artist Royalty - Wholesale` → `artist_royalties_wholesale`
#    - `Artist Royalty - Interiors` → `artist_royalties_interiors`
# 5. ✅ Uploaded artists to Strapi API with error handling and logging
#
# ### Key Features:
# - Robust error handling for network issues and API errors
# - Comprehensive logging for tracking progress
# - Environment variables for sensitive credentials
# - Rate limiting to avoid overwhelming the API
# - Detailed success/failure reporting
#
# ### Future Improvements:
# 1. **Duplicate checking**: Query existing artists before upload to avoid duplicates
# 2. **Batch operations**: If API supports it, batch uploads for better performance
# 3. **Retry logic**: Implement automatic retry for failed uploads
# 4. **Data validation**: Add pre-upload validation for royalty rate ranges
# 5. **Update capability**: Add logic to update existing artists instead of only creating new ones
# 6. **Export results**: Save upload results to a CSV file for record-keeping
