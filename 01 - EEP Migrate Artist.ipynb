# %% [markdown]
# # Artist Data Migration to Strapi API
#
# This notebook processes artist data from CSV and uploads it to the Strapi database via API.
#
# ## Process:
# 1. Load CSV data with artist information
# 2. Extract unique artists with their royalty rates
# 3. Clean and prepare data
# 4. Upload to API endpoint
# 5. Log results and handle errors

# %%
# Out:
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, dotenv
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [dotenv]
# Successfully installed dotenv-0.9.9 python-dotenv-1.1.1

# %%
# Import required libraries
import pandas as pd
import numpy as np
import requests
import json
import os
from dotenv import load_dotenv
import logging
from typing import Dict, List, Optional
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

# Load environment variables
load_dotenv()

# API Configuration
API_BASE_URL = os.getenv('API_BASE_URL')
API_TOKEN = os.getenv('API_TOKEN')

if not API_BASE_URL or not API_TOKEN:
    raise ValueError("API_BASE_URL and API_TOKEN must be set in .env file")

logger.info(f"API Base URL: {API_BASE_URL}")
logger.info("API Token loaded successfully")
# Out:
# 2025-10-20 11:14:12,129 - INFO - API Base URL: https://renowned-flowers-a42cef227c.strapiapp.com/api
# 2025-10-20 11:14:12,130 - INFO - API Token loaded successfully

# %%
# Load CSV data
csv_file_path = 'data/All Product Data Back Up 070825.csv'

logger.info(f"Loading CSV file: {csv_file_path}")

try:
    # Read CSV file - only load relevant columns for efficiency
    df = pd.read_csv(
        csv_file_path,
        usecols=['Artist', 'Artist Royalty - Retail', 'Artist Royalty - Wholesale', 'Artist Royalty - Interiors']
    )
    logger.info(f"Successfully loaded {len(df)} rows from CSV")
    logger.info(f"Columns: {df.columns.tolist()}")
    
    # Display first few rows
    print("\nFirst 5 rows of data:")
    print(df.head())
    
except Exception as e:
    logger.error(f"Error loading CSV file: {e}")
    raise
# Out:
# 2025-10-20 11:14:28,314 - INFO - Loading CSV file: data/All Product Data Back Up 070825.csv
# 2025-10-20 11:14:37,595 - INFO - Successfully loaded 384349 rows from CSV
# 2025-10-20 11:14:37,597 - INFO - Columns: ['Artist', 'Artist Royalty - Retail', 'Artist Royalty - Wholesale', 'Artist Royalty - Interiors']
# First 5 rows of data:
#           Artist  Artist Royalty - Retail  Artist Royalty - Wholesale  \
# 0  The 13 Prints                     3.99                         1.1
# 1  The 13 Prints                     3.99                         1.1
# 2  The 13 Prints                     3.99                         1.1
# 3  The 13 Prints                     3.99                         1.1
# 4  The 13 Prints                     3.99                         1.1
#
#    Artist Royalty - Interiors
# 0                         1.4
# 1                         1.4
# 2                         1.4
# 3                         1.4
# 4                         1.4

# %%
# Process and clean data to get unique artists with their royalty rates
logger.info("Processing artist data...")

# Remove rows where Artist is null or empty
df_clean = df.dropna(subset=['Artist'])
df_clean = df_clean[df_clean['Artist'].str.strip() != '']

logger.info(f"After removing nulls/empties: {len(df_clean)} rows")

# Get unique artists with their royalty rates
# Using groupby to get the first occurrence of each artist's royalty rates
# (assuming royalty rates are consistent per artist)
unique_artists_df = df_clean.groupby('Artist', as_index=False).first()

logger.info(f"Found {len(unique_artists_df)} unique artists")

# Display the processed data
print("\nUnique Artists Data:")
print(unique_artists_df)
print(f"\nTotal unique artists: {len(unique_artists_df)}")

# Check for any missing royalty data
missing_retail = unique_artists_df['Artist Royalty - Retail'].isna().sum()
missing_wholesale = unique_artists_df['Artist Royalty - Wholesale'].isna().sum()
missing_interiors = unique_artists_df['Artist Royalty - Interiors'].isna().sum()

print(f"\nMissing data summary:")
print(f"  - Missing Retail Royalty: {missing_retail}")
print(f"  - Missing Wholesale Royalty: {missing_wholesale}")
print(f"  - Missing Interiors Royalty: {missing_interiors}")
# Out:
# 2025-10-20 11:15:04,528 - INFO - Processing artist data...
# 2025-10-20 11:15:04,633 - INFO - After removing nulls/empties: 381721 rows
# 2025-10-20 11:15:04,653 - INFO - Found 279 unique artists
# Unique Artists Data:
#               Artist  Artist Royalty - Retail  Artist Royalty - Wholesale  \
# 0             67 Inc                      NaN                         NaN
# 1         83 Oranges                     3.99                        1.10
# 2         Adam Graff                      NaN                         NaN
# 3          Aley Wild                     3.99                        1.10
# 4      Alice Straker                     3.99                        1.10
# ..               ...                      ...                         ...
# 274  Your Local Ross                     3.99                        1.10
# 275    apricot+birch                     3.99                        1.10
# 276       blanchouse                     3.99                        0.66
# 277         cartissi                     3.99                        1.10
# 278             m00d                     3.99                        1.10
#
#      Artist Royalty - Interiors
# 0                           NaN
# 1                           1.4
# 2                           NaN
# 3                           1.4
# 4                           1.4
# ..                          ...
# 274                         1.4
# 275                         1.4
# 276                         1.4
# 277                         1.4
# 278                         1.4
#
# [279 rows x 4 columns]
#
# Total unique artists: 279
#
# Missing data summary:
#   - Missing Retail Royalty: 76
#   - Missing Wholesale Royalty: 58
#   - Missing Interiors Royalty: 76

# %%
# Function to create artist via API
def create_artist(artist_data: Dict) -> Optional[Dict]:
    """
    Create an artist record in the Strapi database via API.
    
    Args:
        artist_data: Dictionary containing artist information
        
    Returns:
        Response data if successful, None if failed
    """
    endpoint = f"{API_BASE_URL}/artists"
    
    headers = {
        'Authorization': f'Bearer {API_TOKEN}',
        'Content-Type': 'application/json'
    }
    
    # Prepare payload according to Strapi format
    payload = {
        "data": artist_data
    }
    
    try:
        response = requests.post(endpoint, headers=headers, json=payload, timeout=30)
        
        if response.status_code == 200 or response.status_code == 201:
            logger.info(f"Successfully created artist: {artist_data.get('artist_name')}")
            return response.json()
        else:
            logger.error(f"Failed to create artist {artist_data.get('artist_name')}: {response.status_code}")
            logger.error(f"Response: {response.text}")
            return None
            
    except requests.exceptions.RequestException as e:
        logger.error(f"Network error creating artist {artist_data.get('artist_name')}: {e}")
        return None
    except Exception as e:
        logger.error(f"Unexpected error creating artist {artist_data.get('artist_name')}: {e}")
        return None

# Test function is defined
logger.info("Artist creation function defined successfully")
# Out:
# 2025-10-20 11:30:12,486 - INFO - Artist creation function defined successfully

# %%
# Prepare artist data for API upload
def prepare_artist_data(row) -> Dict:
    """
    Transform DataFrame row into API-compatible artist data format.
    
    Args:
        row: DataFrame row containing artist information
        
    Returns:
        Dictionary with API field names and cleaned values
    """
    artist_data = {
        "artist_name": str(row['Artist']).strip(),
        "artist_royalties_retail": None,
        "artist_royalties_wholesale": None,
        "artist_royalties_interiors": None
    }
    
    # Handle royalty values - convert to float if not null
    if pd.notna(row['Artist Royalty - Retail']):
        artist_data["artist_royalties_retail"] = float(row['Artist Royalty - Retail'])
    
    if pd.notna(row['Artist Royalty - Wholesale']):
        artist_data["artist_royalties_wholesale"] = float(row['Artist Royalty - Wholesale'])
    
    if pd.notna(row['Artist Royalty - Interiors']):
        artist_data["artist_royalties_interiors"] = float(row['Artist Royalty - Interiors'])
    
    return artist_data

# Prepare all artist records
artist_records = []
for idx, row in unique_artists_df.iterrows():
    artist_data = prepare_artist_data(row)
    artist_records.append(artist_data)

logger.info(f"Prepared {len(artist_records)} artist records for upload")

# Display sample prepared data
print("\nSample prepared artist data (first 3):")
for i, record in enumerate(artist_records[:3]):
    print(f"\n{i+1}. {json.dumps(record, indent=2)}")
# Out:
# 2025-10-20 11:31:19,891 - INFO - Prepared 279 artist records for upload
# Sample prepared artist data (first 3):
#
# 1. {
#   "artist_name": "67 Inc",
#   "artist_royalties_retail": null,
#   "artist_royalties_wholesale": null,
#   "artist_royalties_interiors": null
# }
#
# 2. {
#   "artist_name": "83 Oranges",
#   "artist_royalties_retail": 3.99,
#   "artist_royalties_wholesale": 1.1,
#   "artist_royalties_interiors": 1.4
# }
#
# 3. {
#   "artist_name": "Adam Graff",
#   "artist_royalties_retail": null,
#   "artist_royalties_wholesale": null,
#   "artist_royalties_interiors": null
# }

# %%
# Upload artists to API
logger.info("Starting artist upload process...")

# Track results
successful_uploads = []
failed_uploads = []
upload_results = {
    'total': len(artist_records),
    'successful': 0,
    'failed': 0,
    'errors': []
}

# Upload each artist with a small delay to avoid overwhelming the API
for i, artist_data in enumerate(artist_records, 1):
    artist_name = artist_data.get('artist_name')
    
    logger.info(f"Uploading artist {i}/{len(artist_records)}: {artist_name}")
    
    result = create_artist(artist_data)
    
    if result:
        successful_uploads.append(artist_name)
        upload_results['successful'] += 1
    else:
        failed_uploads.append(artist_name)
        upload_results['failed'] += 1
        upload_results['errors'].append(f"Failed to upload: {artist_name}")
    
    # Small delay to avoid rate limiting (adjust as needed)
    time.sleep(0.5)

# Display results summary
print("\n" + "="*60)
print("UPLOAD SUMMARY")
print("="*60)
print(f"Total artists processed: {upload_results['total']}")
print(f"Successful uploads: {upload_results['successful']}")
print(f"Failed uploads: {upload_results['failed']}")
print(f"Success rate: {(upload_results['successful']/upload_results['total']*100):.2f}%")

if failed_uploads:
    print(f"\nFailed artists ({len(failed_uploads)}):")
    for artist in failed_uploads:
        print(f"  - {artist}")

logger.info("Artist upload process completed")
# Out:
# 2025-10-20 11:31:27,681 - INFO - Starting artist upload process...
# 2025-10-20 11:31:27,682 - INFO - Uploading artist 1/279: 67 Inc
# 2025-10-20 11:31:28,570 - INFO - Successfully created artist: 67 Inc
# 2025-10-20 11:31:29,077 - INFO - Uploading artist 2/279: 83 Oranges
# 2025-10-20 11:31:29,436 - INFO - Successfully created artist: 83 Oranges
# 2025-10-20 11:31:29,947 - INFO - Uploading artist 3/279: Adam Graff
# 2025-10-20 11:31:30,291 - INFO - Successfully created artist: Adam Graff
# 2025-10-20 11:31:30,794 - INFO - Uploading artist 4/279: Aley Wild
# 2025-10-20 11:31:31,167 - INFO - Successfully created artist: Aley Wild
# 2025-10-20 11:31:31,672 - INFO - Uploading artist 5/279: Alice Straker
# 2025-10-20 11:31:32,045 - INFO - Successfully created artist: Alice Straker
# 2025-10-20 11:31:32,554 - INFO - Uploading artist 6/279: Alisa Galitsyna
# 2025-10-20 11:31:32,880 - INFO - Successfully created artist: Alisa Galitsyna
# 2025-10-20 11:31:33,387 - INFO - Uploading artist 7/279: Amanda Adam
# 2025-10-20 11:31:33,705 - INFO - Successfully created artist: Amanda Adam
# 2025-10-20 11:31:34,212 - INFO - Uploading artist 8/279: Amy Hastings
# 2025-10-20 11:31:34,557 - INFO - Successfully created artist: Amy Hastings
# 2025-10-20 11:31:35,067 - INFO - Uploading artist 9/279: Ana Jaks
# 2025-10-20 11:31:35,391 - INFO - Successfully created artist: Ana Jaks
# 2025-10-20 11:31:35,907 - INFO - Uploading artist 10/279: Ana Rut Bre
# 2025-10-20 11:31:36,251 - INFO - Successfully created artist: Ana Rut Bre
# 2025-10-20 11:31:36,762 - INFO - Uploading artist 11/279: Anek
# 2025-10-20 11:31:37,087 - INFO - Successfully created artist: Anek
# 2025-10-20 11:31:37,594 - INFO - Uploading artist 12/279: Ani Vidotto
# 2025-10-20 11:31:37,923 - INFO - Successfully created artist: Ani Vidotto
# 2025-10-20 11:31:38,431 - INFO - Uploading artist 13/279: Anna Mainz
# 2025-10-20 11:31:38,754 - INFO - Successfully created artist: Anna Mainz
# 2025-10-20 11:31:39,262 - INFO - Uploading artist 14/279: Anna Schmidt
# 2025-10-20 11:31:39,593 - INFO - Successfully created artist: Anna Schmidt
# 2025-10-20 11:31:40,101 - INFO - Uploading artist 15/279: Anthony Peters
# 2025-10-20 11:31:40,429 - INFO - Successfully created artist: Anthony Peters
# 2025-10-20 11:31:40,939 - INFO - Uploading artist 16/279: Anthony Peters
# 2025-10-20 11:31:41,276 - INFO - Successfully created artist: Anthony Peters
# 2025-10-20 11:31:41,782 - INFO - Uploading artist 17/279: Artist Named Nobody
# 2025-10-20 11:31:42,167 - INFO - Successfully created artist: Artist Named Nobody
# 2025-10-20 11:31:42,677 - INFO - Uploading artist 18/279: Arty Guava
# 2025-10-20 11:31:42,999 - INFO - Successfully created artist: Arty Guava
# 2025-10-20 11:31:43,511 - INFO - Uploading artist 19/279: Aster
# 2025-10-20 11:31:43,843 - INFO - Successfully created artist: Aster
# 2025-10-20 11:31:44,352 - INFO - Uploading artist 20/279: Asteronyme
# 2025-10-20 11:31:44,663 - INFO - Successfully created artist: Asteronyme
# 2025-10-20 11:31:45,174 - INFO - Uploading artist 21/279: Basil & Ford
# 2025-10-20 11:31:45,528 - INFO - Successfully created artist: Basil & Ford
# 2025-10-20 11:31:46,038 - INFO - Uploading artist 22/279: Becca Boyce
# 2025-10-20 11:31:46,355 - INFO - Successfully created artist: Becca Boyce
# 2025-10-20 11:31:46,859 - INFO - Uploading artist 23/279: Becca Who
# 2025-10-20 11:31:47,182 - INFO - Successfully created artist: Becca Who
# 2025-10-20 11:31:47,689 - INFO - Uploading artist 24/279: Becks Norf Design
# 2025-10-20 11:31:48,013 - INFO - Successfully created artist: Becks Norf Design
# 2025-10-20 11:31:48,521 - INFO - Uploading artist 25/279: Ben Rothery
# 2025-10-20 11:31:48,870 - INFO - Successfully created artist: Ben Rothery
# 2025-10-20 11:31:49,374 - INFO - Uploading artist 26/279: Bethany Young
# 2025-10-20 11:31:49,709 - INFO - Successfully created artist: Bethany Young
# 2025-10-20 11:31:50,217 - INFO - Uploading artist 27/279: Bianca Green
# 2025-10-20 11:31:50,579 - INFO - Successfully created artist: Bianca Green
# 2025-10-20 11:31:51,086 - INFO - Uploading artist 28/279: Billy The Kid
# 2025-10-20 11:31:51,407 - INFO - Successfully created artist: Billy The Kid
# 2025-10-20 11:31:51,915 - INFO - Uploading artist 29/279: Bo Lundberg
# 2025-10-20 11:31:52,251 - INFO - Successfully created artist: Bo Lundberg
# 2025-10-20 11:31:52,758 - INFO - Uploading artist 30/279: Bob & Eve
# 2025-10-20 11:31:53,099 - INFO - Successfully created artist: Bob & Eve
# 2025-10-20 11:31:53,602 - INFO - Uploading artist 31/279: Caitlin Keegan
# 2025-10-20 11:31:53,928 - INFO - Successfully created artist: Caitlin Keegan
# 2025-10-20 11:31:54,438 - INFO - Uploading artist 32/279: Caitlin Park
# 2025-10-20 11:31:54,771 - INFO - Successfully created artist: Caitlin Park
# 2025-10-20 11:31:55,276 - INFO - Uploading artist 33/279: Capricorn Press
# 2025-10-20 11:31:55,608 - INFO - Successfully created artist: Capricorn Press
# 2025-10-20 11:31:56,114 - INFO - Uploading artist 34/279: Carolin Loebbert
# 2025-10-20 11:31:56,438 - INFO - Successfully created artist: Carolin Loebbert
# 2025-10-20 11:31:56,947 - INFO - Uploading artist 35/279: Cat Coquillette
# 2025-10-20 11:31:57,298 - INFO - Successfully created artist: Cat Coquillette
# 2025-10-20 11:31:57,808 - INFO - Uploading artist 36/279: Catford Creative
# 2025-10-20 11:31:58,498 - INFO - Successfully created artist: Catford Creative
# 2025-10-20 11:31:59,007 - INFO - Uploading artist 37/279: Charlie Taylor
# 2025-10-20 11:31:59,328 - INFO - Successfully created artist: Charlie Taylor
# 2025-10-20 11:31:59,840 - INFO - Uploading artist 38/279: Christina Hagerfors
# 2025-10-20 11:32:00,174 - INFO - Successfully created artist: Christina Hagerfors
# 2025-10-20 11:32:00,687 - INFO - Uploading artist 39/279: Coco de Paris
# 2025-10-20 11:32:01,010 - INFO - Successfully created artist: Coco de Paris
# 2025-10-20 11:32:01,518 - INFO - Uploading artist 40/279: Coit Creative
# 2025-10-20 11:32:01,856 - INFO - Successfully created artist: Coit Creative
# 2025-10-20 11:32:02,366 - INFO - Uploading artist 41/279: Colour TV
# 2025-10-20 11:32:02,692 - INFO - Successfully created artist: Colour TV
# 2025-10-20 11:32:03,209 - INFO - Uploading artist 42/279: Crayon Studio
# 2025-10-20 11:32:03,534 - INFO - Successfully created artist: Crayon Studio
# 2025-10-20 11:32:04,040 - INFO - Uploading artist 43/279: Dale Edwin Murray
# 2025-10-20 11:32:04,362 - INFO - Successfully created artist: Dale Edwin Murray
# 2025-10-20 11:32:04,869 - INFO - Uploading artist 44/279: Dan Hobday
# 2025-10-20 11:32:05,193 - INFO - Successfully created artist: Dan Hobday
# 2025-10-20 11:32:05,704 - INFO - Uploading artist 45/279: Daniel Battams
# 2025-10-20 11:32:06,057 - INFO - Successfully created artist: Daniel Battams
# 2025-10-20 11:32:06,566 - INFO - Uploading artist 46/279: Daniel Haskett
# 2025-10-20 11:32:06,907 - INFO - Successfully created artist: Daniel Haskett
# 2025-10-20 11:32:07,411 - INFO - Uploading artist 47/279: Darcie Olley
# 2025-10-20 11:32:07,739 - INFO - Successfully created artist: Darcie Olley
# 2025-10-20 11:32:08,244 - INFO - Uploading artist 48/279: Deltanova
# 2025-10-20 11:32:08,559 - INFO - Successfully created artist: Deltanova
# 2025-10-20 11:32:09,072 - INFO - Uploading artist 49/279: Dicky Bird
# 2025-10-20 11:32:09,403 - INFO - Successfully created artist: Dicky Bird
# 2025-10-20 11:32:09,907 - INFO - Uploading artist 50/279: Dieter Braun
# 2025-10-20 11:32:10,247 - INFO - Successfully created artist: Dieter Braun
# 2025-10-20 11:32:10,762 - INFO - Uploading artist 51/279: Don't Grow Up
# 2025-10-20 11:32:11,079 - INFO - Successfully created artist: Don't Grow Up
# 2025-10-20 11:32:11,582 - INFO - Uploading artist 52/279: Doodle Moo
# 2025-10-20 11:32:11,911 - INFO - Successfully created artist: Doodle Moo
# 2025-10-20 11:32:12,419 - INFO - Uploading artist 53/279: Doodle by Meg
# 2025-10-20 11:32:12,739 - INFO - Successfully created artist: Doodle by Meg
# 2025-10-20 11:32:13,246 - INFO - Uploading artist 54/279: Dorothy
# 2025-10-20 11:32:13,623 - INFO - Successfully created artist: Dorothy
# 2025-10-20 11:32:14,126 - INFO - Uploading artist 55/279: Double Merrick
# 2025-10-20 11:32:14,456 - INFO - Successfully created artist: Double Merrick
# 2025-10-20 11:32:14,962 - INFO - Uploading artist 56/279: Dreamy Me
# 2025-10-20 11:32:15,293 - INFO - Successfully created artist: Dreamy Me
# 2025-10-20 11:32:15,803 - INFO - Uploading artist 57/279: EEP Design
# 2025-10-20 11:32:16,118 - INFO - Successfully created artist: EEP Design
# 2025-10-20 11:32:16,628 - INFO - Uploading artist 58/279: East London Print House
# 2025-10-20 11:32:16,950 - INFO - Successfully created artist: East London Print House
# 2025-10-20 11:32:17,459 - INFO - Uploading artist 59/279: Ec Mazur
# 2025-10-20 11:32:17,772 - INFO - Successfully created artist: Ec Mazur
# 2025-10-20 11:32:18,281 - INFO - Uploading artist 60/279: El Famoso
# 2025-10-20 11:32:18,594 - INFO - Successfully created artist: El Famoso
# 2025-10-20 11:32:19,098 - INFO - Uploading artist 61/279: Elena Boils
# 2025-10-20 11:32:19,421 - INFO - Successfully created artist: Elena Boils
# 2025-10-20 11:32:19,928 - INFO - Uploading artist 62/279: Emily Powell
# 2025-10-20 11:32:20,251 - INFO - Successfully created artist: Emily Powell
# 2025-10-20 11:32:20,761 - INFO - Uploading artist 63/279: Emmy Lupin Studio
# 2025-10-20 11:32:21,080 - INFO - Successfully created artist: Emmy Lupin Studio
# 2025-10-20 11:32:21,584 - INFO - Uploading artist 64/279: Eve Print Studio
# 2025-10-20 11:32:21,901 - INFO - Successfully created artist: Eve Print Studio
# 2025-10-20 11:32:22,411 - INFO - Uploading artist 65/279: Exquisite Paradox
# 2025-10-20 11:32:22,738 - INFO - Successfully created artist: Exquisite Paradox
# 2025-10-20 11:32:23,245 - INFO - Uploading artist 66/279: Eye for London
# 2025-10-20 11:32:23,567 - INFO - Successfully created artist: Eye for London
# 2025-10-20 11:32:24,075 - INFO - Uploading artist 67/279: Fan Club
# 2025-10-20 11:32:24,394 - INFO - Successfully created artist: Fan Club
# 2025-10-20 11:32:24,901 - INFO - Uploading artist 68/279: Fiona Watson
# 2025-10-20 11:32:25,233 - INFO - Successfully created artist: Fiona Watson
# 2025-10-20 11:32:25,741 - INFO - Uploading artist 69/279: Flood Gallery
# 2025-10-20 11:32:26,067 - INFO - Successfully created artist: Flood Gallery
# 2025-10-20 11:32:26,574 - INFO - Uploading artist 70/279: Florent Bodart
# 2025-10-20 11:32:26,885 - INFO - Successfully created artist: Florent Bodart
# 2025-10-20 11:32:27,391 - INFO - Uploading artist 71/279: Flower Love Child
# 2025-10-20 11:32:27,723 - INFO - Successfully created artist: Flower Love Child
# 2025-10-20 11:32:28,232 - INFO - Uploading artist 72/279: Fox and Velvet
# 2025-10-20 11:32:28,558 - INFO - Successfully created artist: Fox and Velvet
# 2025-10-20 11:32:29,068 - INFO - Uploading artist 73/279: Frame Only
# 2025-10-20 11:32:29,392 - INFO - Successfully created artist: Frame Only
# 2025-10-20 11:32:29,902 - INFO - Uploading artist 74/279: Frances Collett
# 2025-10-20 11:32:30,243 - INFO - Successfully created artist: Frances Collett
# 2025-10-20 11:32:30,749 - INFO - Uploading artist 75/279: Francesca Iannaccone
# 2025-10-20 11:32:31,070 - INFO - Successfully created artist: Francesca Iannaccone
# 2025-10-20 11:32:31,578 - INFO - Uploading artist 76/279: Frank Moth
# 2025-10-20 11:32:31,919 - INFO - Successfully created artist: Frank Moth
# 2025-10-20 11:32:32,435 - INFO - Uploading artist 77/279: Frankk Studio
# 2025-10-20 11:32:32,750 - INFO - Successfully created artist: Frankk Studio
# 2025-10-20 11:32:33,257 - INFO - Uploading artist 78/279: Freya MacPhail
# 2025-10-20 11:32:33,580 - INFO - Successfully created artist: Freya MacPhail
# 2025-10-20 11:32:34,088 - INFO - Uploading artist 79/279: GS Print Shoppe
# 2025-10-20 11:32:34,413 - INFO - Successfully created artist: GS Print Shoppe
# 2025-10-20 11:32:34,923 - INFO - Uploading artist 80/279: Gal+Goose
# 2025-10-20 11:32:35,269 - INFO - Successfully created artist: Gal+Goose
# 2025-10-20 11:32:35,775 - INFO - Uploading artist 81/279: Garima Dhawan
# 2025-10-20 11:32:36,108 - INFO - Successfully created artist: Garima Dhawan
# 2025-10-20 11:32:36,617 - INFO - Uploading artist 82/279: Golden Daze
# 2025-10-20 11:32:36,937 - INFO - Successfully created artist: Golden Daze
# 2025-10-20 11:32:37,446 - INFO - Uploading artist 83/279: Hali Igwelaezoh
# 2025-10-20 11:32:37,772 - INFO - Successfully created artist: Hali Igwelaezoh
# 2025-10-20 11:32:38,280 - INFO - Uploading artist 84/279: Hand Jazz
# 2025-10-20 11:32:38,610 - INFO - Successfully created artist: Hand Jazz
# 2025-10-20 11:32:39,118 - INFO - Uploading artist 85/279: Hanna Melin
# 2025-10-20 11:32:39,448 - INFO - Successfully created artist: Hanna Melin
# 2025-10-20 11:32:39,956 - INFO - Uploading artist 86/279: Hannah Gilson
# 2025-10-20 11:32:40,281 - INFO - Successfully created artist: Hannah Gilson
# 2025-10-20 11:32:40,788 - INFO - Uploading artist 87/279: Hello Bonjour
# 2025-10-20 11:32:41,127 - INFO - Successfully created artist: Hello Bonjour
# 2025-10-20 11:32:41,634 - INFO - Uploading artist 88/279: Herald Black
# 2025-10-20 11:32:41,983 - INFO - Successfully created artist: Herald Black
# 2025-10-20 11:32:42,494 - INFO - Uploading artist 89/279: HollieGraphik
# 2025-10-20 11:32:42,823 - INFO - Successfully created artist: HollieGraphik
# 2025-10-20 11:32:43,331 - INFO - Uploading artist 90/279: Honey Island Studio
# 2025-10-20 11:32:43,650 - INFO - Successfully created artist: Honey Island Studio
# 2025-10-20 11:32:44,158 - INFO - Uploading artist 91/279: Honeymoon Hotel
# 2025-10-20 11:32:44,499 - INFO - Successfully created artist: Honeymoon Hotel
# 2025-10-20 11:32:45,003 - INFO - Uploading artist 92/279: I Ended Up Here
# 2025-10-20 11:32:45,373 - INFO - Successfully created artist: I Ended Up Here
# 2025-10-20 11:32:45,881 - INFO - Uploading artist 93/279: Ian Stevenson
# 2025-10-20 11:32:46,209 - INFO - Successfully created artist: Ian Stevenson
# 2025-10-20 11:32:46,719 - INFO - Uploading artist 94/279: Illustrated by Charlie
# 2025-10-20 11:32:47,050 - INFO - Successfully created artist: Illustrated by Charlie
# 2025-10-20 11:32:47,559 - INFO - Uploading artist 95/279: Illustrated by Weezy
# 2025-10-20 11:32:47,875 - INFO - Successfully created artist: Illustrated by Weezy
# 2025-10-20 11:32:48,381 - INFO - Uploading artist 96/279: Indieprints
# 2025-10-20 11:32:48,713 - INFO - Successfully created artist: Indieprints
# 2025-10-20 11:32:49,219 - INFO - Uploading artist 97/279: Ingrid Beddoes
# 2025-10-20 11:32:49,568 - INFO - Successfully created artist: Ingrid Beddoes
# 2025-10-20 11:32:50,075 - INFO - Uploading artist 98/279: Ink OnK
# 2025-10-20 11:32:50,411 - INFO - Successfully created artist: Ink OnK
# 2025-10-20 11:32:50,919 - INFO - Uploading artist 99/279: Ink Tally
# 2025-10-20 11:32:51,263 - INFO - Successfully created artist: Ink Tally
# 2025-10-20 11:32:51,777 - INFO - Uploading artist 100/279: Inoui
# 2025-10-20 11:32:52,134 - INFO - Successfully created artist: Inoui
# 2025-10-20 11:32:52,643 - INFO - Uploading artist 101/279: Iris Lehnhardt
# 2025-10-20 11:32:52,983 - INFO - Successfully created artist: Iris Lehnhardt
# 2025-10-20 11:32:53,494 - INFO - Uploading artist 102/279: Jack Sinnot
# 2025-10-20 11:32:53,828 - INFO - Successfully created artist: Jack Sinnot
# 2025-10-20 11:32:54,337 - INFO - Uploading artist 103/279: Jack Sinnott
# 2025-10-20 11:32:54,668 - INFO - Successfully created artist: Jack Sinnott
# 2025-10-20 11:32:55,172 - INFO - Uploading artist 104/279: Jacqueline Colley
# 2025-10-20 11:32:55,509 - INFO - Successfully created artist: Jacqueline Colley
# 2025-10-20 11:32:56,015 - INFO - Uploading artist 105/279: James Brown
# 2025-10-20 11:32:56,352 - INFO - Successfully created artist: James Brown
# 2025-10-20 11:32:56,860 - INFO - Uploading artist 106/279: James Campbell Taylor
# 2025-10-20 11:32:57,213 - INFO - Successfully created artist: James Campbell Taylor
# 2025-10-20 11:32:57,720 - INFO - Uploading artist 107/279: Jane Smith
# 2025-10-20 11:32:58,057 - INFO - Successfully created artist: Jane Smith
# 2025-10-20 11:32:58,563 - INFO - Uploading artist 108/279: Jason Ratliff
# 2025-10-20 11:32:58,898 - INFO - Successfully created artist: Jason Ratliff
# 2025-10-20 11:32:59,404 - INFO - Uploading artist 109/279: Jay Fleck
# 2025-10-20 11:32:59,723 - INFO - Successfully created artist: Jay Fleck
# 2025-10-20 11:33:00,240 - INFO - Uploading artist 110/279: Jayson Lilley
# 2025-10-20 11:33:00,581 - INFO - Successfully created artist: Jayson Lilley
# 2025-10-20 11:33:01,083 - INFO - Uploading artist 111/279: Jazmine Joye
# 2025-10-20 11:33:01,433 - INFO - Successfully created artist: Jazmine Joye
# 2025-10-20 11:33:01,941 - INFO - Uploading artist 112/279: Jazzberry Blue
# 2025-10-20 11:33:02,295 - INFO - Successfully created artist: Jazzberry Blue
# 2025-10-20 11:33:02,803 - INFO - Uploading artist 113/279: Jess Wilson
# 2025-10-20 11:33:03,152 - INFO - Successfully created artist: Jess Wilson
# 2025-10-20 11:33:03,657 - INFO - Uploading artist 114/279: Joanna Mudrowska
# 2025-10-20 11:33:04,005 - INFO - Successfully created artist: Joanna Mudrowska
# 2025-10-20 11:33:04,514 - INFO - Uploading artist 115/279: Johanna von Holst
# 2025-10-20 11:33:04,854 - INFO - Successfully created artist: Johanna von Holst
# 2025-10-20 11:33:05,362 - INFO - Uploading artist 116/279: Jorgen Hansson
# 2025-10-20 11:33:05,693 - INFO - Successfully created artist: Jorgen Hansson
# 2025-10-20 11:33:06,196 - INFO - Uploading artist 117/279: Judy Andrews
# 2025-10-20 11:33:06,534 - INFO - Successfully created artist: Judy Andrews
# 2025-10-20 11:33:07,041 - INFO - Uploading artist 118/279: Julia Noble
# 2025-10-20 11:33:07,370 - INFO - Successfully created artist: Julia Noble
# 2025-10-20 11:33:07,877 - INFO - Uploading artist 119/279: Julia Ockert
# 2025-10-20 11:33:08,530 - INFO - Successfully created artist: Julia Ockert
# 2025-10-20 11:33:09,037 - INFO - Uploading artist 120/279: Julia Walck
# 2025-10-20 11:33:09,371 - INFO - Successfully created artist: Julia Walck
# 2025-10-20 11:33:09,875 - INFO - Uploading artist 121/279: Julie Lavender
# 2025-10-20 11:33:10,204 - INFO - Successfully created artist: Julie Lavender
# 2025-10-20 11:33:10,708 - INFO - Uploading artist 122/279: KaloolaJay Studio
# 2025-10-20 11:33:11,019 - INFO - Successfully created artist: KaloolaJay Studio
# 2025-10-20 11:33:11,533 - INFO - Uploading artist 123/279: Karin Akesson
# 2025-10-20 11:33:11,878 - INFO - Successfully created artist: Karin Akesson
# 2025-10-20 11:33:12,389 - INFO - Uploading artist 124/279: Kartika Paramita
# 2025-10-20 11:33:12,718 - INFO - Successfully created artist: Kartika Paramita
# 2025-10-20 11:33:13,227 - INFO - Uploading artist 125/279: Katy Edelsten
# 2025-10-20 11:33:13,538 - INFO - Successfully created artist: Katy Edelsten
# 2025-10-20 11:33:14,046 - INFO - Uploading artist 126/279: Katy Smail
# 2025-10-20 11:33:14,385 - INFO - Successfully created artist: Katy Smail
# 2025-10-20 11:33:14,897 - INFO - Uploading artist 127/279: Katy Welsh
# 2025-10-20 11:33:15,271 - INFO - Successfully created artist: Katy Welsh
# 2025-10-20 11:33:15,780 - INFO - Uploading artist 128/279: Kavel Rafferty
# 2025-10-20 11:33:16,125 - INFO - Successfully created artist: Kavel Rafferty
# 2025-10-20 11:33:16,634 - INFO - Uploading artist 129/279: Keeler & Sidaway
# 2025-10-20 11:33:16,974 - INFO - Successfully created artist: Keeler & Sidaway
# 2025-10-20 11:33:17,477 - INFO - Uploading artist 130/279: Keren Parmley
# 2025-10-20 11:33:17,805 - INFO - Successfully created artist: Keren Parmley
# 2025-10-20 11:33:18,310 - INFO - Uploading artist 131/279: Kid of the Village
# 2025-10-20 11:33:18,634 - INFO - Successfully created artist: Kid of the Village
# 2025-10-20 11:33:19,140 - INFO - Uploading artist 132/279: Kubistika
# 2025-10-20 11:33:19,472 - INFO - Successfully created artist: Kubistika
# 2025-10-20 11:33:19,980 - INFO - Uploading artist 133/279: Laura Knight
# 2025-10-20 11:33:20,308 - INFO - Successfully created artist: Laura Knight
# 2025-10-20 11:33:20,816 - INFO - Uploading artist 134/279: Laura Page
# 2025-10-20 11:33:21,150 - INFO - Successfully created artist: Laura Page
# 2025-10-20 11:33:21,658 - INFO - Uploading artist 135/279: Layover Art
# 2025-10-20 11:33:21,988 - INFO - Successfully created artist: Layover Art
# 2025-10-20 11:33:22,497 - INFO - Uploading artist 136/279: Leanne Simpson
# 2025-10-20 11:33:22,828 - INFO - Successfully created artist: Leanne Simpson
# 2025-10-20 11:33:23,336 - INFO - Uploading artist 137/279: Lemon Fee
# 2025-10-20 11:33:23,660 - INFO - Successfully created artist: Lemon Fee
# 2025-10-20 11:33:24,171 - INFO - Uploading artist 138/279: Limbo and Ginger
# 2025-10-20 11:33:24,514 - INFO - Successfully created artist: Limbo and Ginger
# 2025-10-20 11:33:25,021 - INFO - Uploading artist 139/279: Linda Gobeta
# 2025-10-20 11:33:25,339 - INFO - Successfully created artist: Linda Gobeta
# 2025-10-20 11:33:25,843 - INFO - Uploading artist 140/279: Little Lark
# 2025-10-20 11:33:26,171 - INFO - Successfully created artist: Little Lark
# 2025-10-20 11:33:26,676 - INFO - Uploading artist 141/279: Lizzie Prestt
# 2025-10-20 11:33:27,021 - INFO - Successfully created artist: Lizzie Prestt
# 2025-10-20 11:33:27,529 - INFO - Uploading artist 142/279: Lollipop Studio
# 2025-10-20 11:33:27,881 - INFO - Successfully created artist: Lollipop Studio
# 2025-10-20 11:33:28,385 - INFO - Uploading artist 143/279: Lora O'Callaghan
# 2025-10-20 11:33:28,708 - INFO - Successfully created artist: Lora O'Callaghan
# 2025-10-20 11:33:29,212 - INFO - Uploading artist 144/279: Lucie Sheridan
# 2025-10-20 11:33:29,542 - INFO - Successfully created artist: Lucie Sheridan
# 2025-10-20 11:33:30,047 - INFO - Uploading artist 145/279: Lucky Budgie
# 2025-10-20 11:33:30,360 - INFO - Successfully created artist: Lucky Budgie
# 2025-10-20 11:33:30,871 - INFO - Uploading artist 146/279: Lucy Merriman
# 2025-10-20 11:33:31,211 - INFO - Successfully created artist: Lucy Merriman
# 2025-10-20 11:33:31,719 - INFO - Uploading artist 147/279: Lucy Muss
# 2025-10-20 11:33:32,059 - INFO - Successfully created artist: Lucy Muss
# 2025-10-20 11:33:32,569 - INFO - Uploading artist 148/279: Luxe Poster Co
# 2025-10-20 11:33:32,897 - INFO - Successfully created artist: Luxe Poster Co
# 2025-10-20 11:33:33,404 - INFO - Uploading artist 149/279: Magnus Myhre
# 2025-10-20 11:33:33,736 - INFO - Successfully created artist: Magnus Myhre
# 2025-10-20 11:33:34,241 - INFO - Uploading artist 150/279: Mahin Hussain
# 2025-10-20 11:33:34,585 - INFO - Successfully created artist: Mahin Hussain
# 2025-10-20 11:33:35,092 - INFO - Uploading artist 151/279: Marcus Walters
# 2025-10-20 11:33:35,432 - INFO - Successfully created artist: Marcus Walters
# 2025-10-20 11:33:35,940 - INFO - Uploading artist 152/279: Mareike Boehmer
# 2025-10-20 11:33:36,256 - INFO - Successfully created artist: Mareike Boehmer
# 2025-10-20 11:33:36,767 - INFO - Uploading artist 153/279: Mariery Young
# 2025-10-20 11:33:37,106 - INFO - Successfully created artist: Mariery Young
# 2025-10-20 11:33:37,615 - INFO - Uploading artist 154/279: Marina Ester Castaldo
# 2025-10-20 11:33:37,938 - INFO - Successfully created artist: Marina Ester Castaldo
# 2025-10-20 11:33:38,447 - INFO - Uploading artist 155/279: Mark Harrison
# 2025-10-20 11:33:38,776 - INFO - Successfully created artist: Mark Harrison
# 2025-10-20 11:33:39,291 - INFO - Uploading artist 156/279: Matchbox Labels
# 2025-10-20 11:33:39,618 - INFO - Successfully created artist: Matchbox Labels
# 2025-10-20 11:33:40,143 - INFO - Uploading artist 157/279: Melissa North
# 2025-10-20 11:33:40,465 - INFO - Successfully created artist: Melissa North
# 2025-10-20 11:33:40,975 - INFO - Uploading artist 158/279: Miho Art Studio
# 2025-10-20 11:33:41,301 - INFO - Successfully created artist: Miho Art Studio
# 2025-10-20 11:33:41,807 - INFO - Uploading artist 159/279: Mike Hall
# 2025-10-20 11:33:42,138 - INFO - Successfully created artist: Mike Hall
# 2025-10-20 11:33:42,644 - INFO - Uploading artist 160/279: Min Pin
# 2025-10-20 11:33:42,952 - INFO - Successfully created artist: Min Pin
# 2025-10-20 11:33:43,457 - INFO - Uploading artist 161/279: Miscellaneous
# 2025-10-20 11:33:43,783 - INFO - Successfully created artist: Miscellaneous
# 2025-10-20 11:33:44,292 - INFO - Uploading artist 162/279: Mother & Sun Studio
# 2025-10-20 11:33:44,620 - INFO - Successfully created artist: Mother & Sun Studio
# 2025-10-20 11:33:45,124 - INFO - Uploading artist 163/279: MsGonzalez
# 2025-10-20 11:33:45,447 - INFO - Successfully created artist: MsGonzalez
# 2025-10-20 11:33:45,955 - INFO - Uploading artist 164/279: Nancy McKie
# 2025-10-20 11:33:46,275 - INFO - Successfully created artist: Nancy McKie
# 2025-10-20 11:33:46,783 - INFO - Uploading artist 165/279: Natalie Cass
# 2025-10-20 11:33:47,123 - INFO - Successfully created artist: Natalie Cass
# 2025-10-20 11:33:47,633 - INFO - Uploading artist 166/279: Nia Beynon
# 2025-10-20 11:33:47,954 - INFO - Successfully created artist: Nia Beynon
# 2025-10-20 11:33:48,460 - INFO - Uploading artist 167/279: Nice Draws
# 2025-10-20 11:33:48,792 - INFO - Successfully created artist: Nice Draws
# 2025-10-20 11:33:49,305 - INFO - Uploading artist 168/279: Nichola Cowdery
# 2025-10-20 11:33:49,861 - INFO - Successfully created artist: Nichola Cowdery
# 2025-10-20 11:33:50,374 - INFO - Uploading artist 169/279: North 6 Graphic Design
# 2025-10-20 11:33:50,697 - INFO - Successfully created artist: North 6 Graphic Design
# 2025-10-20 11:33:51,209 - INFO - Uploading artist 170/279: OHH DEER
# 2025-10-20 11:33:51,549 - INFO - Successfully created artist: OHH DEER
# 2025-10-20 11:33:52,056 - INFO - Uploading artist 171/279: OKNO
# 2025-10-20 11:33:52,372 - INFO - Successfully created artist: OKNO
# 2025-10-20 11:33:52,880 - INFO - Uploading artist 172/279: Oh Fine! Art
# 2025-10-20 11:33:53,188 - INFO - Successfully created artist: Oh Fine! Art
# 2025-10-20 11:33:53,696 - INFO - Uploading artist 173/279: Olivia Axson
# 2025-10-20 11:33:54,015 - INFO - Successfully created artist: Olivia Axson
# 2025-10-20 11:33:54,520 - INFO - Uploading artist 174/279: One Gog
# 2025-10-20 11:33:54,842 - INFO - Successfully created artist: One Gog
# 2025-10-20 11:33:55,349 - INFO - Uploading artist 175/279: Oshe POP!
# 2025-10-20 11:33:55,682 - INFO - Successfully created artist: Oshe POP!
# 2025-10-20 11:33:56,191 - INFO - Uploading artist 176/279: Parrott Paints
# 2025-10-20 11:33:56,514 - INFO - Successfully created artist: Parrott Paints
# 2025-10-20 11:33:57,026 - INFO - Uploading artist 177/279: Paul Hamilton
# 2025-10-20 11:33:57,352 - INFO - Successfully created artist: Paul Hamilton
# 2025-10-20 11:33:57,861 - INFO - Uploading artist 178/279: Philip Sheffield
# 2025-10-20 11:33:58,180 - INFO - Successfully created artist: Philip Sheffield
# 2025-10-20 11:33:58,691 - INFO - Uploading artist 179/279: Places & Spaces Art Co
# 2025-10-20 11:33:59,062 - INFO - Successfully created artist: Places & Spaces Art Co
# 2025-10-20 11:33:59,566 - INFO - Uploading artist 180/279: Planet Patrol
# 2025-10-20 11:33:59,894 - INFO - Successfully created artist: Planet Patrol
# 2025-10-20 11:34:00,404 - INFO - Uploading artist 181/279: Poet and Painter
# 2025-10-20 11:34:00,742 - INFO - Successfully created artist: Poet and Painter
# 2025-10-20 11:34:01,246 - INFO - Uploading artist 182/279: Printer Johnson
# 2025-10-20 11:34:01,586 - INFO - Successfully created artist: Printer Johnson
# 2025-10-20 11:34:02,090 - INFO - Uploading artist 183/279: Protest Nation
# 2025-10-20 11:34:02,420 - INFO - Successfully created artist: Protest Nation
# 2025-10-20 11:34:02,929 - INFO - Uploading artist 184/279: Pulp Brother
# 2025-10-20 11:34:03,282 - INFO - Successfully created artist: Pulp Brother
# 2025-10-20 11:34:03,790 - INFO - Uploading artist 185/279: Rachel Lee
# 2025-10-20 11:34:04,130 - INFO - Successfully created artist: Rachel Lee
# 2025-10-20 11:34:04,641 - INFO - Uploading artist 186/279: Rachel Locke
# 2025-10-20 11:34:05,001 - INFO - Successfully created artist: Rachel Locke
# 2025-10-20 11:34:05,508 - INFO - Uploading artist 187/279: Rafael Farias
# 2025-10-20 11:34:05,842 - INFO - Successfully created artist: Rafael Farias
# 2025-10-20 11:34:06,347 - INFO - Uploading artist 188/279: Rawhide
# 2025-10-20 11:34:06,675 - INFO - Successfully created artist: Rawhide
# 2025-10-20 11:34:07,183 - INFO - Uploading artist 189/279: Rebecca Morcombe Young
# 2025-10-20 11:34:07,524 - INFO - Successfully created artist: Rebecca Morcombe Young
# 2025-10-20 11:34:08,032 - INFO - Uploading artist 190/279: Rebecca Strickson
# 2025-10-20 11:34:08,440 - INFO - Successfully created artist: Rebecca Strickson
# 2025-10-20 11:34:08,947 - INFO - Uploading artist 191/279: Red Faces Prints
# 2025-10-20 11:34:09,301 - INFO - Successfully created artist: Red Faces Prints
# 2025-10-20 11:34:09,806 - INFO - Uploading artist 192/279: Rhianna Marie Chan
# 2025-10-20 11:34:10,136 - INFO - Successfully created artist: Rhianna Marie Chan
# 2025-10-20 11:34:10,641 - INFO - Uploading artist 193/279: Rocket 68
# 2025-10-20 11:34:10,953 - INFO - Successfully created artist: Rocket 68
# 2025-10-20 11:34:11,462 - INFO - Uploading artist 194/279: Rocket Jack
# 2025-10-20 11:34:11,800 - INFO - Successfully created artist: Rocket Jack
# 2025-10-20 11:34:12,312 - INFO - Uploading artist 195/279: Rosi Feist
# 2025-10-20 11:34:12,663 - INFO - Successfully created artist: Rosi Feist
# 2025-10-20 11:34:13,170 - INFO - Uploading artist 196/279: Ruben Ireland
# 2025-10-20 11:34:13,491 - INFO - Successfully created artist: Ruben Ireland
# 2025-10-20 11:34:14,001 - INFO - Uploading artist 197/279: Rude
# 2025-10-20 11:34:14,326 - INFO - Successfully created artist: Rude
# 2025-10-20 11:34:14,835 - INFO - Uploading artist 198/279: SHIO
# 2025-10-20 11:34:15,170 - INFO - Successfully created artist: SHIO
# 2025-10-20 11:34:15,679 - INFO - Uploading artist 199/279: Sam Capell
# 2025-10-20 11:34:16,023 - INFO - Successfully created artist: Sam Capell
# 2025-10-20 11:34:16,530 - INFO - Uploading artist 200/279: Sammy Hearn
# 2025-10-20 11:34:16,853 - INFO - Successfully created artist: Sammy Hearn
# 2025-10-20 11:34:17,372 - INFO - Uploading artist 201/279: Sandra Poliakov
# 2025-10-20 11:34:17,714 - INFO - Successfully created artist: Sandra Poliakov
# 2025-10-20 11:34:18,222 - INFO - Uploading artist 202/279: Say It With Songs
# 2025-10-20 11:34:18,542 - INFO - Successfully created artist: Say It With Songs
# 2025-10-20 11:34:19,053 - INFO - Uploading artist 203/279: Scribbler
# 2025-10-20 11:34:19,390 - INFO - Successfully created artist: Scribbler
# 2025-10-20 11:34:19,913 - INFO - Uploading artist 204/279: Sean Butler
# 2025-10-20 11:34:20,266 - INFO - Successfully created artist: Sean Butler
# 2025-10-20 11:34:20,780 - INFO - Uploading artist 205/279: Seekprint
# 2025-10-20 11:34:21,123 - INFO - Successfully created artist: Seekprint
# 2025-10-20 11:34:21,631 - INFO - Uploading artist 206/279: Sei and Ru
# 2025-10-20 11:34:21,962 - INFO - Successfully created artist: Sei and Ru
# 2025-10-20 11:34:22,468 - INFO - Uploading artist 207/279: Seventy Tree
# 2025-10-20 11:34:22,780 - INFO - Successfully created artist: Seventy Tree
# 2025-10-20 11:34:23,289 - INFO - Uploading artist 208/279: She Snacks and Paints
# 2025-10-20 11:34:23,603 - INFO - Successfully created artist: She Snacks and Paints
# 2025-10-20 11:34:24,107 - INFO - Uploading artist 209/279: Show Me Mars
# 2025-10-20 11:34:24,433 - INFO - Successfully created artist: Show Me Mars
# 2025-10-20 11:34:24,944 - INFO - Uploading artist 210/279: Sifa Mustafa
# 2025-10-20 11:34:25,282 - INFO - Successfully created artist: Sifa Mustafa
# 2025-10-20 11:34:25,789 - INFO - Uploading artist 211/279: Simon C Page
# 2025-10-20 11:34:26,123 - INFO - Successfully created artist: Simon C Page
# 2025-10-20 11:34:26,632 - INFO - Uploading artist 212/279: SimplyExtraJordanary
# 2025-10-20 11:34:26,970 - INFO - Successfully created artist: SimplyExtraJordanary
# 2025-10-20 11:34:27,475 - INFO - Uploading artist 213/279: Sisi and Seb
# 2025-10-20 11:34:27,845 - INFO - Successfully created artist: Sisi and Seb
# 2025-10-20 11:34:28,348 - INFO - Uploading artist 214/279: Sofia Doudine
# 2025-10-20 11:34:28,676 - INFO - Successfully created artist: Sofia Doudine
# 2025-10-20 11:34:29,185 - INFO - Uploading artist 215/279: Sophia Ward
# 2025-10-20 11:34:29,536 - INFO - Successfully created artist: Sophia Ward
# 2025-10-20 11:34:30,045 - INFO - Uploading artist 216/279: Sophie Harding
# 2025-10-20 11:34:30,368 - INFO - Successfully created artist: Sophie Harding
# 2025-10-20 11:34:30,872 - INFO - Uploading artist 217/279: Sophie Ward
# 2025-10-20 11:34:31,215 - INFO - Successfully created artist: Sophie Ward
# 2025-10-20 11:34:31,725 - INFO - Uploading artist 218/279: Sshepaints
# 2025-10-20 11:34:32,056 - INFO - Successfully created artist: Sshepaints
# 2025-10-20 11:34:32,564 - INFO - Uploading artist 219/279: Stephie Cardona
# 2025-10-20 11:34:32,882 - INFO - Successfully created artist: Stephie Cardona
# 2025-10-20 11:34:33,388 - INFO - Uploading artist 220/279: Stu Is Cool
# 2025-10-20 11:34:33,712 - INFO - Successfully created artist: Stu Is Cool
# 2025-10-20 11:34:34,217 - INFO - Uploading artist 221/279: Studio Cockatoo
# 2025-10-20 11:34:34,567 - INFO - Successfully created artist: Studio Cockatoo
# 2025-10-20 11:34:35,075 - INFO - Uploading artist 222/279: Studio Eleni
# 2025-10-20 11:34:35,399 - INFO - Successfully created artist: Studio Eleni
# 2025-10-20 11:34:35,907 - INFO - Uploading artist 223/279: Studio Na.hili
# 2025-10-20 11:34:36,285 - INFO - Successfully created artist: Studio Na.hili
# 2025-10-20 11:34:36,795 - INFO - Uploading artist 224/279: Summer Du Plessis
# 2025-10-20 11:34:37,146 - INFO - Successfully created artist: Summer Du Plessis
# 2025-10-20 11:34:37,654 - INFO - Uploading artist 225/279: Summer du Plessis
# 2025-10-20 11:34:38,000 - INFO - Successfully created artist: Summer du Plessis
# 2025-10-20 11:34:38,507 - INFO - Uploading artist 226/279: Sumuyya Khader
# 2025-10-20 11:34:38,848 - INFO - Successfully created artist: Sumuyya Khader
# 2025-10-20 11:34:39,352 - INFO - Uploading artist 227/279: Sundry Society
# 2025-10-20 11:34:39,682 - INFO - Successfully created artist: Sundry Society
# 2025-10-20 11:34:40,189 - INFO - Uploading artist 228/279: Supermundane
# 2025-10-20 11:34:40,547 - INFO - Successfully created artist: Supermundane
# 2025-10-20 11:34:41,051 - INFO - Uploading artist 229/279: Susan Taylor Design
# 2025-10-20 11:34:41,369 - INFO - Successfully created artist: Susan Taylor Design
# 2025-10-20 11:34:41,880 - INFO - Uploading artist 230/279: Susana Paz
# 2025-10-20 11:34:42,201 - INFO - Successfully created artist: Susana Paz
# 2025-10-20 11:34:42,710 - INFO - Uploading artist 231/279: Susie Miller
# 2025-10-20 11:34:43,037 - INFO - Successfully created artist: Susie Miller
# 2025-10-20 11:34:43,545 - INFO - Uploading artist 232/279: Swifty Jazz
# 2025-10-20 11:34:43,850 - INFO - Successfully created artist: Swifty Jazz
# 2025-10-20 11:34:44,358 - INFO - Uploading artist 233/279: Sylvia Moritz
# 2025-10-20 11:34:44,683 - INFO - Successfully created artist: Sylvia Moritz
# 2025-10-20 11:34:45,188 - INFO - Uploading artist 234/279: Tartagain
# 2025-10-20 11:34:45,525 - INFO - Successfully created artist: Tartagain
# 2025-10-20 11:34:46,032 - INFO - Uploading artist 235/279: Telegramme Paper Co.
# 2025-10-20 11:34:46,369 - INFO - Successfully created artist: Telegramme Paper Co.
# 2025-10-20 11:34:46,875 - INFO - Uploading artist 236/279: Teresa Rego
# 2025-10-20 11:34:47,189 - INFO - Successfully created artist: Teresa Rego
# 2025-10-20 11:34:47,699 - INFO - Uploading artist 237/279: The 13 Prints
# 2025-10-20 11:34:48,413 - INFO - Successfully created artist: The 13 Prints
# 2025-10-20 11:34:48,923 - INFO - Uploading artist 238/279: The Colour Study
# 2025-10-20 11:34:49,246 - INFO - Successfully created artist: The Colour Study
# 2025-10-20 11:34:49,755 - INFO - Uploading artist 239/279: The Designers Nursery
# 2025-10-20 11:34:50,091 - INFO - Successfully created artist: The Designers Nursery
# 2025-10-20 11:34:50,596 - INFO - Uploading artist 240/279: The Dybdahl Co
# 2025-10-20 11:34:50,940 - INFO - Successfully created artist: The Dybdahl Co
# 2025-10-20 11:34:51,447 - INFO - Uploading artist 241/279: The Melomaniac
# 2025-10-20 11:34:51,765 - INFO - Successfully created artist: The Melomaniac
# 2025-10-20 11:34:52,272 - INFO - Uploading artist 242/279: The Native State
# 2025-10-20 11:34:52,600 - INFO - Successfully created artist: The Native State
# 2025-10-20 11:34:53,110 - INFO - Uploading artist 243/279: The Natural History Museum
# 2025-10-20 11:34:53,458 - INFO - Successfully created artist: The Natural History Museum
# 2025-10-20 11:34:53,964 - INFO - Uploading artist 244/279: The Pattern Press
# 2025-10-20 11:34:54,312 - INFO - Successfully created artist: The Pattern Press
# 2025-10-20 11:34:54,816 - INFO - Uploading artist 245/279: The Stereo Typist
# 2025-10-20 11:34:55,157 - INFO - Successfully created artist: The Stereo Typist
# 2025-10-20 11:34:55,665 - INFO - Uploading artist 246/279: The Violet Eclectic
# 2025-10-20 11:34:56,002 - INFO - Successfully created artist: The Violet Eclectic
# 2025-10-20 11:34:56,506 - INFO - Uploading artist 247/279: This Charming Print
# 2025-10-20 11:34:56,841 - INFO - Successfully created artist: This Charming Print
# 2025-10-20 11:34:57,353 - INFO - Uploading artist 248/279: Thoth Adan
# 2025-10-20 11:34:57,697 - INFO - Successfully created artist: Thoth Adan
# 2025-10-20 11:34:58,205 - INFO - Uploading artist 249/279: Tiffany Lynch
# 2025-10-20 11:34:58,534 - INFO - Successfully created artist: Tiffany Lynch
# 2025-10-20 11:34:59,040 - INFO - Uploading artist 250/279: Tiger Spirit Prints
# 2025-10-20 11:34:59,381 - INFO - Successfully created artist: Tiger Spirit Prints
# 2025-10-20 11:34:59,885 - INFO - Uploading artist 251/279: Tiny Riot
# 2025-10-20 11:35:00,225 - INFO - Successfully created artist: Tiny Riot
# 2025-10-20 11:35:00,736 - INFO - Uploading artist 252/279: Tom Pigeon
# 2025-10-20 11:35:01,042 - INFO - Successfully created artist: Tom Pigeon
# 2025-10-20 11:35:01,551 - INFO - Uploading artist 253/279: Tomartacus
# 2025-10-20 11:35:01,891 - INFO - Successfully created artist: Tomartacus
# 2025-10-20 11:35:02,398 - INFO - Uploading artist 254/279: Tony Green
# 2025-10-20 11:35:02,725 - INFO - Successfully created artist: Tony Green
# 2025-10-20 11:35:03,233 - INFO - Uploading artist 255/279: Tracie Andrews
# 2025-10-20 11:35:03,561 - INFO - Successfully created artist: Tracie Andrews
# 2025-10-20 11:35:04,070 - INFO - Uploading artist 256/279: Tree x Three
# 2025-10-20 11:35:04,387 - INFO - Successfully created artist: Tree x Three
# 2025-10-20 11:35:04,897 - INFO - Uploading artist 257/279: Twisted Rebel Design
# 2025-10-20 11:35:05,221 - INFO - Successfully created artist: Twisted Rebel Design
# 2025-10-20 11:35:05,734 - INFO - Uploading artist 258/279: Twisted Rebel Designs
# 2025-10-20 11:35:06,037 - INFO - Successfully created artist: Twisted Rebel Designs
# 2025-10-20 11:35:06,546 - INFO - Uploading artist 259/279: U Studio
# 2025-10-20 11:35:06,867 - INFO - Successfully created artist: U Studio
# 2025-10-20 11:35:07,374 - INFO - Uploading artist 260/279: Uncool John
# 2025-10-20 11:35:07,703 - INFO - Successfully created artist: Uncool John
# 2025-10-20 11:35:08,210 - INFO - Uploading artist 261/279: Underway Studio
# 2025-10-20 11:35:08,541 - INFO - Successfully created artist: Underway Studio
# 2025-10-20 11:35:09,048 - INFO - Uploading artist 262/279: Vertigo Artography
# 2025-10-20 11:35:09,369 - INFO - Successfully created artist: Vertigo Artography
# 2025-10-20 11:35:09,877 - INFO - Uploading artist 263/279: Vicky Langdon
# 2025-10-20 11:35:10,234 - INFO - Successfully created artist: Vicky Langdon
# 2025-10-20 11:35:10,743 - INFO - Uploading artist 264/279: Vincent Trinidad
# 2025-10-20 11:35:11,128 - INFO - Successfully created artist: Vincent Trinidad
# 2025-10-20 11:35:11,637 - INFO - Uploading artist 265/279: Vintage by Hemingway
# 2025-10-20 11:35:11,930 - INFO - Successfully created artist: Vintage by Hemingway
# 2025-10-20 11:35:12,434 - INFO - Uploading artist 266/279: Violet Studio
# 2025-10-20 11:35:12,749 - INFO - Successfully created artist: Violet Studio
# 2025-10-20 11:35:13,258 - INFO - Uploading artist 267/279: Wacka
# 2025-10-20 11:35:13,579 - INFO - Successfully created artist: Wacka
# 2025-10-20 11:35:14,083 - INFO - Uploading artist 268/279: Wall Chart
# 2025-10-20 11:35:14,389 - INFO - Successfully created artist: Wall Chart
# 2025-10-20 11:35:14,903 - INFO - Uploading artist 269/279: We Made Something Nice
# 2025-10-20 11:35:15,246 - INFO - Successfully created artist: We Made Something Nice
# 2025-10-20 11:35:15,751 - INFO - Uploading artist 270/279: Wildsuga
# 2025-10-20 11:35:16,046 - INFO - Successfully created artist: Wildsuga
# 2025-10-20 11:35:16,556 - INFO - Uploading artist 271/279: Will Clarke
# 2025-10-20 11:35:16,873 - INFO - Successfully created artist: Will Clarke
# 2025-10-20 11:35:17,382 - INFO - Uploading artist 272/279: Woah There Pickle
# 2025-10-20 11:35:17,717 - INFO - Successfully created artist: Woah There Pickle
# 2025-10-20 11:35:18,222 - INFO - Uploading artist 273/279: Wonder and Rah
# 2025-10-20 11:35:18,545 - INFO - Successfully created artist: Wonder and Rah
# 2025-10-20 11:35:19,052 - INFO - Uploading artist 274/279: Word Quirk
# 2025-10-20 11:35:19,405 - INFO - Successfully created artist: Word Quirk
# 2025-10-20 11:35:19,910 - INFO - Uploading artist 275/279: Your Local Ross
# 2025-10-20 11:35:20,252 - INFO - Successfully created artist: Your Local Ross
# 2025-10-20 11:35:20,759 - INFO - Uploading artist 276/279: apricot+birch
# 2025-10-20 11:35:21,168 - INFO - Successfully created artist: apricot+birch
# 2025-10-20 11:35:21,676 - INFO - Uploading artist 277/279: blanchouse
# 2025-10-20 11:35:22,015 - INFO - Successfully created artist: blanchouse
# 2025-10-20 11:35:22,526 - INFO - Uploading artist 278/279: cartissi
# 2025-10-20 11:35:22,873 - INFO - Successfully created artist: cartissi
# 2025-10-20 11:35:23,381 - INFO - Uploading artist 279/279: m00d
# 2025-10-20 11:35:23,686 - INFO - Successfully created artist: m00d
# 2025-10-20 11:35:24,192 - INFO - Artist upload process completed
# ============================================================
# UPLOAD SUMMARY
# ============================================================
# Total artists processed: 279
# Successful uploads: 279
# Failed uploads: 0
# Success rate: 100.00%

# %% [raw]
# ## Summary and Recommendations
#
# ### What was done:
# 1. ✅ Loaded CSV data containing artist information
# 2. ✅ Extracted unique artist names with their royalty rates
# 3. ✅ Cleaned and validated data
# 4. ✅ Mapped CSV columns to API field names:
#    - `Artist` → `artist_name`
#    - `Artist Royalty - Retail` → `artist_royalties_retail`
#    - `Artist Royalty - Wholesale` → `artist_royalties_wholesale`
#    - `Artist Royalty - Interiors` → `artist_royalties_interiors`
# 5. ✅ Uploaded artists to Strapi API with error handling and logging
#
# ### Key Features:
# - Robust error handling for network issues and API errors
# - Comprehensive logging for tracking progress
# - Environment variables for sensitive credentials
# - Rate limiting to avoid overwhelming the API
# - Detailed success/failure reporting
#
# ### Future Improvements:
# 1. **Duplicate checking**: Query existing artists before upload to avoid duplicates
# 2. **Batch operations**: If API supports it, batch uploads for better performance
# 3. **Retry logic**: Implement automatic retry for failed uploads
# 4. **Data validation**: Add pre-upload validation for royalty rate ranges
# 5. **Update capability**: Add logic to update existing artists instead of only creating new ones
# 6. **Export results**: Save upload results to a CSV file for record-keeping
